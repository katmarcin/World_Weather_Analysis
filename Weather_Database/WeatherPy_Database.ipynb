# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
 #Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | ostrovnoy
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | san rafael
# Processing Record 5 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | katsiveli
# City not found. Skipping...
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 1 | rudkobing
# Processing Record 13 of Set 1 | kaohsiung
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | altamira
# Processing Record 17 of Set 1 | papara
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | kita
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | darhan
# Processing Record 22 of Set 1 | iwanai
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | ninghai
# Processing Record 26 of Set 1 | pundaguitan
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | spokane
# Processing Record 29 of Set 1 | wasilla
# Processing Record 30 of Set 1 | jawar
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | belyy yar
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | grindavik
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | lata
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | broken hill
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | asau
# Processing Record 46 of Set 1 | asmara
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | coihaique
# Processing Record 50 of Set 1 | mount gambier
# Processing Record 1 of Set 2 | srednekolymsk
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | orchard homes
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | latung
# Processing Record 8 of Set 2 | ahuimanu
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | rio tercero
# Processing Record 11 of Set 2 | college
# Processing Record 12 of Set 2 | tome-acu
# City not found. Skipping...
# Processing Record 13 of Set 2 | port-gentil
# Processing Record 14 of Set 2 | aksarayskiy
# Processing Record 15 of Set 2 | jalu
# Processing Record 16 of Set 2 | torquay
# Processing Record 17 of Set 2 | okhotsk
# Processing Record 18 of Set 2 | oktyabrskiy
# Processing Record 19 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 2 | boyolangu
# Processing Record 21 of Set 2 | amboasary
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | ayagoz
# Processing Record 25 of Set 2 | kropotkin
# Processing Record 26 of Set 2 | saldanha
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | katsuura
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | carupano
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | barrow
# Processing Record 33 of Set 2 | banda aceh
# Processing Record 34 of Set 2 | solnechnyy
# Processing Record 35 of Set 2 | nanortalik
# Processing Record 36 of Set 2 | paracuru
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | asayita
# City not found. Skipping...
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | tual
# Processing Record 42 of Set 2 | malyye derbety
# Processing Record 43 of Set 2 | sale
# Processing Record 44 of Set 2 | namatanai
# Processing Record 45 of Set 2 | san fernando
# Processing Record 46 of Set 2 | airai
# Processing Record 47 of Set 2 | sorong
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | clyde river
# Processing Record 50 of Set 2 | san cristobal
# Processing Record 1 of Set 3 | svetlogorsk
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | bereda
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | marzuq
# Processing Record 7 of Set 3 | lebu
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | adrar
# Processing Record 10 of Set 3 | rawson
# Processing Record 11 of Set 3 | yamasaki
# Processing Record 12 of Set 3 | rio gallegos
# Processing Record 13 of Set 3 | borama
# City not found. Skipping...
# Processing Record 14 of Set 3 | coquimbo
# Processing Record 15 of Set 3 | bengkulu
# Processing Record 16 of Set 3 | ivanteyevka
# Processing Record 17 of Set 3 | weyburn
# Processing Record 18 of Set 3 | sumbe
# Processing Record 19 of Set 3 | kant
# Processing Record 20 of Set 3 | vardo
# Processing Record 21 of Set 3 | turukhansk
# Processing Record 22 of Set 3 | salinas
# Processing Record 23 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | cherskiy
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | kuusamo
# Processing Record 27 of Set 3 | pacific grove
# Processing Record 28 of Set 3 | oswego
# Processing Record 29 of Set 3 | klaksvik
# Processing Record 30 of Set 3 | kochubey
# Processing Record 31 of Set 3 | honiara
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | flowing wells
# Processing Record 34 of Set 3 | leningradskiy
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | terracina
# Processing Record 38 of Set 3 | kingaroy
# Processing Record 39 of Set 3 | tirumullaivasal
# Processing Record 40 of Set 3 | khatanga
# Processing Record 41 of Set 3 | kutum
# Processing Record 42 of Set 3 | touros
# Processing Record 43 of Set 3 | sidi ali
# Processing Record 44 of Set 3 | puerto ayacucho
# Processing Record 45 of Set 3 | oudtshoorn
# Processing Record 46 of Set 3 | muzquiz
# City not found. Skipping...
# Processing Record 47 of Set 3 | kuytun
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 3 | tayibe
# City not found. Skipping...
# Processing Record 50 of Set 3 | provideniya
# Processing Record 1 of Set 4 | perpignan
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | margate
# Processing Record 4 of Set 4 | mkushi
# Processing Record 5 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 4 | port moresby
# Processing Record 7 of Set 4 | gemena
# Processing Record 8 of Set 4 | jiaozuo
# Processing Record 9 of Set 4 | villanueva
# Processing Record 10 of Set 4 | moyale
# Processing Record 11 of Set 4 | kandrian
# Processing Record 12 of Set 4 | san patricio
# Processing Record 13 of Set 4 | bansi
# Processing Record 14 of Set 4 | tabas
# Processing Record 15 of Set 4 | koshurnikovo
# Processing Record 16 of Set 4 | birao
# Processing Record 17 of Set 4 | lorengau
# Processing Record 18 of Set 4 | zhigansk
# Processing Record 19 of Set 4 | neath
# Processing Record 20 of Set 4 | tahe
# Processing Record 21 of Set 4 | san vicente
# Processing Record 22 of Set 4 | collie
# Processing Record 23 of Set 4 | isangel
# Processing Record 24 of Set 4 | andahuaylas
# Processing Record 25 of Set 4 | vaini
# Processing Record 26 of Set 4 | emmett
# Processing Record 27 of Set 4 | uribia
# Processing Record 28 of Set 4 | jamestown
# Processing Record 29 of Set 4 | chokurdakh
# Processing Record 30 of Set 4 | puerto quijarro
# Processing Record 31 of Set 4 | vuktyl
# Processing Record 32 of Set 4 | wattegama
# Processing Record 33 of Set 4 | slave lake
# Processing Record 34 of Set 4 | sydney mines
# Processing Record 35 of Set 4 | havre
# Processing Record 36 of Set 4 | gbarnga
# Processing Record 37 of Set 4 | jasper
# Processing Record 38 of Set 4 | mareeba
# Processing Record 39 of Set 4 | medford
# Processing Record 40 of Set 4 | makakilo city
# Processing Record 41 of Set 4 | parana
# Processing Record 42 of Set 4 | guerrero negro
# Processing Record 43 of Set 4 | constitucion
# Processing Record 44 of Set 4 | bambous virieux
# Processing Record 45 of Set 4 | codrington
# Processing Record 46 of Set 4 | colesberg
# Processing Record 47 of Set 4 | bengbu
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | wewak
# Processing Record 50 of Set 4 | nuevo progreso
# Processing Record 1 of Set 5 | port lincoln
# Processing Record 2 of Set 5 | nouadhibou
# Processing Record 3 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 5 | belmonte
# Processing Record 5 of Set 5 | kerteh
# City not found. Skipping...
# Processing Record 6 of Set 5 | antofagasta
# Processing Record 7 of Set 5 | sao joao da barra
# Processing Record 8 of Set 5 | praia
# Processing Record 9 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 5 | adre
# Processing Record 11 of Set 5 | jambi
# Processing Record 12 of Set 5 | dormidontovka
# Processing Record 13 of Set 5 | port elizabeth
# Processing Record 14 of Set 5 | sola
# Processing Record 15 of Set 5 | dalhousie
# Processing Record 16 of Set 5 | kampot
# Processing Record 17 of Set 5 | fougamou
# Processing Record 18 of Set 5 | tommot
# Processing Record 19 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 5 | mountain home
# Processing Record 21 of Set 5 | general pico
# Processing Record 22 of Set 5 | ahipara
# Processing Record 23 of Set 5 | yumen
# Processing Record 24 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 5 | maumere
# Processing Record 26 of Set 5 | tilichiki
# Processing Record 27 of Set 5 | husavik
# Processing Record 28 of Set 5 | nelson bay
# Processing Record 29 of Set 5 | portales
# Processing Record 30 of Set 5 | kathu
# Processing Record 31 of Set 5 | tupancireta
# Processing Record 32 of Set 5 | bajos de haina
# Processing Record 33 of Set 5 | severo-kurilsk
# Processing Record 34 of Set 5 | longyearbyen
# Processing Record 35 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 36 of Set 5 | bilma
# Processing Record 37 of Set 5 | rincon
# Processing Record 38 of Set 5 | bagdarin
# Processing Record 39 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 5 | alice springs
# Processing Record 41 of Set 5 | upernavik
# Processing Record 42 of Set 5 | karoi
# Processing Record 43 of Set 5 | kununurra
# Processing Record 44 of Set 5 | pisco
# Processing Record 45 of Set 5 | havre-saint-pierre
# Processing Record 46 of Set 5 | bonthe
# Processing Record 47 of Set 5 | leshukonskoye
# Processing Record 48 of Set 5 | mugur-aksy
# Processing Record 49 of Set 5 | comodoro rivadavia
# Processing Record 50 of Set 5 | cap-aux-meules
# Processing Record 1 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 6 | pedernales
# Processing Record 3 of Set 6 | vagur
# Processing Record 4 of Set 6 | atuona
# Processing Record 5 of Set 6 | cadillac
# Processing Record 6 of Set 6 | vung tau
# Processing Record 7 of Set 6 | puerto cabezas
# Processing Record 8 of Set 6 | gornopravdinsk
# Processing Record 9 of Set 6 | kaitangata
# Processing Record 10 of Set 6 | suntar
# Processing Record 11 of Set 6 | ambon
# Processing Record 12 of Set 6 | veraval
# Processing Record 13 of Set 6 | yichang
# Processing Record 14 of Set 6 | miri
# Processing Record 15 of Set 6 | yarada
# Processing Record 16 of Set 6 | mhlume
# Processing Record 17 of Set 6 | cabo san lucas
# Processing Record 18 of Set 6 | ust-ishim
# Processing Record 19 of Set 6 | tekeli
# Processing Record 20 of Set 6 | guayaramerin
# Processing Record 21 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 6 | lamont
# Processing Record 23 of Set 6 | avarua
# Processing Record 24 of Set 6 | huarmey
# Processing Record 25 of Set 6 | maiduguri
# Processing Record 26 of Set 6 | dehloran
# Processing Record 27 of Set 6 | rogun
# City not found. Skipping...
# Processing Record 28 of Set 6 | pueblo nuevo
# Processing Record 29 of Set 6 | anadyr
# Processing Record 30 of Set 6 | cuajinicuilapa
# Processing Record 31 of Set 6 | westport
# Processing Record 32 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 6 | puerto leguizamo
# Processing Record 34 of Set 6 | mana
# Processing Record 35 of Set 6 | maniitsoq
# Processing Record 36 of Set 6 | porto novo
# Processing Record 37 of Set 6 | maceio
# Processing Record 38 of Set 6 | mecca
# Processing Record 39 of Set 6 | lazaro cardenas
# Processing Record 40 of Set 6 | mwinilunga
# Processing Record 41 of Set 6 | sindor
# Processing Record 42 of Set 6 | saint-georges
# Processing Record 43 of Set 6 | salalah
# Processing Record 44 of Set 6 | talnakh
# Processing Record 45 of Set 6 | sakit
# Processing Record 46 of Set 6 | camana
# Processing Record 47 of Set 6 | acapulco
# Processing Record 48 of Set 6 | belvedere marittimo
# Processing Record 49 of Set 6 | hualmay
# Processing Record 50 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 7 | meulaboh
# Processing Record 2 of Set 7 | araguatins
# City not found. Skipping...
# Processing Record 3 of Set 7 | akyab
# Processing Record 4 of Set 7 | zyryanka
# Processing Record 5 of Set 7 | torbay
# Processing Record 6 of Set 7 | iqaluit
# Processing Record 7 of Set 7 | lavrentiya
# Processing Record 8 of Set 7 | matagami
# Processing Record 9 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 10 of Set 7 | mayo
# Processing Record 11 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | santa rosa
# Processing Record 14 of Set 7 | diamantino
# Processing Record 15 of Set 7 | carutapera
# Processing Record 16 of Set 7 | tessalit
# Processing Record 17 of Set 7 | nkhotakota
# Processing Record 18 of Set 7 | jogbani
# Processing Record 19 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 7 | verkhoyansk
# Processing Record 21 of Set 7 | romny
# Processing Record 22 of Set 7 | gigmoto
# Processing Record 23 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 7 | bousso
# Processing Record 25 of Set 7 | san jeronimo
# Processing Record 26 of Set 7 | melfort
# Processing Record 27 of Set 7 | vila franca do campo
# Processing Record 28 of Set 7 | tornio
# Processing Record 29 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 30 of Set 7 | herzogenburg
# Processing Record 31 of Set 7 | ambilobe
# Processing Record 32 of Set 7 | alta floresta
# Processing Record 33 of Set 7 | gat
# Processing Record 34 of Set 7 | nanyang
# Processing Record 35 of Set 7 | fortuna
# Processing Record 36 of Set 7 | valparaiso
# Processing Record 37 of Set 7 | cabedelo
# Processing Record 38 of Set 7 | inndyr
# Processing Record 39 of Set 7 | kachiry
# Processing Record 40 of Set 7 | miandrivazo
# Processing Record 41 of Set 7 | tuktoyaktuk
# Processing Record 42 of Set 7 | aras
# Processing Record 43 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 7 | cayenne
# Processing Record 45 of Set 7 | ixtapa
# Processing Record 46 of Set 7 | camopi
# Processing Record 47 of Set 7 | paamiut
# Processing Record 48 of Set 7 | kabompo
# Processing Record 49 of Set 7 | kavieng
# Processing Record 50 of Set 7 | kruisfontein
# Processing Record 1 of Set 8 | quatre cocos
# Processing Record 2 of Set 8 | chimbote
# Processing Record 3 of Set 8 | vao
# Processing Record 4 of Set 8 | kavaratti
# Processing Record 5 of Set 8 | florence
# Processing Record 6 of Set 8 | nakhon thai
# Processing Record 7 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 8 of Set 8 | neiafu
# Processing Record 9 of Set 8 | opatija
# Processing Record 10 of Set 8 | alipur duar
# City not found. Skipping...
# Processing Record 11 of Set 8 | chara
# Processing Record 12 of Set 8 | laguna
# Processing Record 13 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 14 of Set 8 | dymer
# Processing Record 15 of Set 8 | agha jari
# City not found. Skipping...
# Processing Record 16 of Set 8 | hami
# Processing Record 17 of Set 8 | galle
# Processing Record 18 of Set 8 | walvis bay
# Processing Record 19 of Set 8 | suhbaatar
# Processing Record 20 of Set 8 | fort nelson
# Processing Record 21 of Set 8 | norman wells
# Processing Record 22 of Set 8 | saint anthony
# Processing Record 23 of Set 8 | kaabong
# Processing Record 24 of Set 8 | muros
# Processing Record 25 of Set 8 | high rock
# Processing Record 26 of Set 8 | progreso
# Processing Record 27 of Set 8 | ranong
# Processing Record 28 of Set 8 | mehriz
# Processing Record 29 of Set 8 | cidreira
# Processing Record 30 of Set 8 | komsomolskiy
# Processing Record 31 of Set 8 | qianan
# Processing Record 32 of Set 8 | camacha
# Processing Record 33 of Set 8 | brigantine
# Processing Record 34 of Set 8 | katangli
# Processing Record 35 of Set 8 | harper
# Processing Record 36 of Set 8 | atar
# Processing Record 37 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 8 | hovd
# Processing Record 39 of Set 8 | port blair
# Processing Record 40 of Set 8 | joshimath
# Processing Record 41 of Set 8 | la reforma
# Processing Record 42 of Set 8 | portlethen
# Processing Record 43 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 45 of Set 8 | naryan-mar
# Processing Record 46 of Set 8 | shache
# Processing Record 47 of Set 8 | montepuez
# Processing Record 48 of Set 8 | anisoc
# Processing Record 49 of Set 8 | tuatapere
# Processing Record 50 of Set 8 | weymouth
# Processing Record 1 of Set 9 | kenai
# Processing Record 2 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 9 | nemuro
# Processing Record 4 of Set 9 | arcachon
# Processing Record 5 of Set 9 | katobu
# Processing Record 6 of Set 9 | flin flon
# Processing Record 7 of Set 9 | lazarev
# Processing Record 8 of Set 9 | half moon bay
# Processing Record 9 of Set 9 | riyadh
# Processing Record 10 of Set 9 | yambio
# Processing Record 11 of Set 9 | riachao das neves
# Processing Record 12 of Set 9 | staryy nadym
# Processing Record 13 of Set 9 | mizoch
# Processing Record 14 of Set 9 | risti
# Processing Record 15 of Set 9 | balikpapan
# Processing Record 16 of Set 9 | naugarzan
# City not found. Skipping...
# Processing Record 17 of Set 9 | nizhniy kuranakh
# Processing Record 18 of Set 9 | bayangol
# Processing Record 19 of Set 9 | sibiti
# Processing Record 20 of Set 9 | teofilo otoni
# Processing Record 21 of Set 9 | ilam
# Processing Record 22 of Set 9 | karratha
# Processing Record 23 of Set 9 | queanbeyan
# Processing Record 24 of Set 9 | hirado
# Processing Record 25 of Set 9 | fairbanks
# Processing Record 26 of Set 9 | lagoa
# Processing Record 27 of Set 9 | yaan
# Processing Record 28 of Set 9 | jumla
# Processing Record 29 of Set 9 | charters towers
# Processing Record 30 of Set 9 | bernalillo
# Processing Record 31 of Set 9 | jaen
# Processing Record 32 of Set 9 | bagua grande
# Processing Record 33 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 34 of Set 9 | marevo
# Processing Record 35 of Set 9 | faya
# Processing Record 36 of Set 9 | bata
# Processing Record 37 of Set 9 | bosanska dubica
# Processing Record 38 of Set 9 | lovington
# Processing Record 39 of Set 9 | te anau
# Processing Record 40 of Set 9 | pangoa
# Processing Record 41 of Set 9 | vagay
# Processing Record 42 of Set 9 | sinnamary
# Processing Record 43 of Set 9 | concepcion del oro
# Processing Record 44 of Set 9 | assiniboia
# Processing Record 45 of Set 9 | nyurba
# Processing Record 46 of Set 9 | khagaria
# Processing Record 47 of Set 9 | boa vista
# Processing Record 48 of Set 9 | yinchuan
# Processing Record 49 of Set 9 | ceska skalice
# Processing Record 50 of Set 9 | bonavista
# Processing Record 1 of Set 10 | esperance
# Processing Record 2 of Set 10 | palmer
# Processing Record 3 of Set 10 | muskogee
# Processing Record 4 of Set 10 | iringa
# Processing Record 5 of Set 10 | mujiayingzi
# Processing Record 6 of Set 10 | taoudenni
# Processing Record 7 of Set 10 | bilibino
# Processing Record 8 of Set 10 | kamina
# Processing Record 9 of Set 10 | tongliao
# Processing Record 10 of Set 10 | labuhan
# Processing Record 11 of Set 10 | maracaju
# Processing Record 12 of Set 10 | san quintin
# Processing Record 13 of Set 10 | dingle
# Processing Record 14 of Set 10 | vaitape
# Processing Record 15 of Set 10 | batagay-alyta
# Processing Record 16 of Set 10 | banfora
# Processing Record 17 of Set 10 | douchy-les-mines
# Processing Record 18 of Set 10 | kailasahar
# City not found. Skipping...
# Processing Record 19 of Set 10 | samarai
# Processing Record 20 of Set 10 | porto velho
# Processing Record 21 of Set 10 | pochutla
# Processing Record 22 of Set 10 | pangody
# Processing Record 23 of Set 10 | camocim
# Processing Record 24 of Set 10 | san policarpo
# Processing Record 25 of Set 10 | kuzedeyevo
# Processing Record 26 of Set 10 | gamba
# Processing Record 27 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 10 | shelburne
# Processing Record 29 of Set 10 | la ciotat
# Processing Record 30 of Set 10 | show low
# Processing Record 31 of Set 10 | umea
# Processing Record 32 of Set 10 | seoul
# Processing Record 33 of Set 10 | bintulu
# Processing Record 34 of Set 10 | muravlenko
# Processing Record 35 of Set 10 | simplicio mendes
# Processing Record 36 of Set 10 | tandil
# Processing Record 37 of Set 10 | ust-maya
# Processing Record 38 of Set 10 | bronnoysund
# Processing Record 39 of Set 10 | mariager
# Processing Record 40 of Set 10 | bubaque
# Processing Record 41 of Set 10 | sioux lookout
# Processing Record 42 of Set 10 | ginir
# Processing Record 43 of Set 10 | concordia
# Processing Record 44 of Set 10 | pangnirtung
# Processing Record 45 of Set 10 | pareora
# Processing Record 46 of Set 10 | jinchang
# Processing Record 47 of Set 10 | hernani
# Processing Record 48 of Set 10 | henties bay
# Processing Record 49 of Set 10 | luang prabang
# Processing Record 50 of Set 10 | port hedland
# Processing Record 1 of Set 11 | mangan
# Processing Record 2 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 3 of Set 11 | iskateley
# Processing Record 4 of Set 11 | rudbar
# Processing Record 5 of Set 11 | zabaykalsk
# Processing Record 6 of Set 11 | tucuman
# Processing Record 7 of Set 11 | sarti
# Processing Record 8 of Set 11 | damghan
# Processing Record 9 of Set 11 | buluang
# Processing Record 10 of Set 11 | yatou
# Processing Record 11 of Set 11 | ayan
# Processing Record 12 of Set 11 | haapsalu
# Processing Record 13 of Set 11 | mbanza-ngungu
# Processing Record 14 of Set 11 | saurimo
# Processing Record 15 of Set 11 | guelph
# Processing Record 16 of Set 11 | tateyama
# Processing Record 17 of Set 11 | ngunguru
# Processing Record 18 of Set 11 | omboue
# Processing Record 19 of Set 11 | kasongo
# Processing Record 20 of Set 11 | saint-pierre
# Processing Record 21 of Set 11 | aklavik
# Processing Record 22 of Set 11 | tazovskiy
# Processing Record 23 of Set 11 | omsukchan
# Processing Record 24 of Set 11 | port hardy
# Processing Record 25 of Set 11 | grootfontein
# Processing Record 26 of Set 11 | umm kaddadah
# Processing Record 27 of Set 11 | buala
# Processing Record 28 of Set 11 | ulaangom
# Processing Record 29 of Set 11 | sistranda
# Processing Record 30 of Set 11 | luderitz
# Processing Record 31 of Set 11 | qandala
# Processing Record 32 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 11 | wanning
# Processing Record 34 of Set 11 | caravelas
# Processing Record 35 of Set 11 | zeya
# Processing Record 36 of Set 11 | hamilton
# Processing Record 37 of Set 11 | chuy
# Processing Record 38 of Set 11 | cornwall
# Processing Record 39 of Set 11 | kalabo
# Processing Record 40 of Set 11 | bafia
# Processing Record 41 of Set 11 | sturgeon falls
# Processing Record 42 of Set 11 | ust-nera
# Processing Record 43 of Set 11 | mehamn
# Processing Record 44 of Set 11 | moose factory
# Processing Record 45 of Set 11 | fomboni
# Processing Record 46 of Set 11 | bima
# Processing Record 47 of Set 11 | bantry
# Processing Record 48 of Set 11 | lac-megantic
# Processing Record 49 of Set 11 | butte
# Processing Record 50 of Set 11 | piacabucu
# Processing Record 1 of Set 12 | alghero
# Processing Record 2 of Set 12 | praia da vitoria
# Processing Record 3 of Set 12 | kachug
# Processing Record 4 of Set 12 | cape coast
# Processing Record 5 of Set 12 | koumac
# Processing Record 6 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 12 | vila velha
# Processing Record 8 of Set 12 | terrace bay
# Processing Record 9 of Set 12 | mingyue
# Processing Record 10 of Set 12 | xining
# Processing Record 11 of Set 12 | teeli
# Processing Record 12 of Set 12 | naqadeh
# Processing Record 13 of Set 12 | lhokseumawe
# Processing Record 14 of Set 12 | lufilufi
# Processing Record 15 of Set 12 | bayji
# Processing Record 16 of Set 12 | ozernovskiy
# Processing Record 17 of Set 12 | nome
# Processing Record 18 of Set 12 | berdigestyakh
# Processing Record 19 of Set 12 | ormond beach
# Processing Record 20 of Set 12 | ternate
# Processing Record 21 of Set 12 | shimoda
# Processing Record 22 of Set 12 | deputatskiy
# Processing Record 23 of Set 12 | chapais
# Processing Record 24 of Set 12 | bontang
# Processing Record 25 of Set 12 | rapid valley
# Processing Record 26 of Set 12 | luanda
# Processing Record 27 of Set 12 | ispravnaya
# Processing Record 28 of Set 12 | atka
# City not found. Skipping...
# Processing Record 29 of Set 12 | shawinigan
# Processing Record 30 of Set 12 | kinablangan
# Processing Record 31 of Set 12 | kumylzhenskaya
# Processing Record 32 of Set 12 | korhogo
# Processing Record 33 of Set 12 | port-cartier
# Processing Record 34 of Set 12 | salvador
# Processing Record 35 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 12 | dingzhou
# Processing Record 37 of Set 12 | naze
# Processing Record 38 of Set 12 | ballybofey
# Processing Record 39 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 40 of Set 12 | paita
# Processing Record 41 of Set 12 | yerbogachen
# Processing Record 42 of Set 12 | parati
# Processing Record 43 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 12 | tolaga bay
# Processing Record 45 of Set 12 | ogulin
# Processing Record 46 of Set 12 | abengourou
# Processing Record 47 of Set 12 | jablah
# Processing Record 48 of Set 12 | ubinskoye
# Processing Record 49 of Set 12 | eyl
# Processing Record 50 of Set 12 | nhulunbuy
# Processing Record 1 of Set 13 | hofn
# Processing Record 2 of Set 13 | lincoln
# Processing Record 3 of Set 13 | nadym
# Processing Record 4 of Set 13 | tomaszow lubelski
# Processing Record 5 of Set 13 | atotonilco el grande
# Processing Record 6 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 7 of Set 13 | lubango
# Processing Record 8 of Set 13 | jhawarian
# Processing Record 9 of Set 13 | okha
# Processing Record 10 of Set 13 | bang saphan
# Processing Record 11 of Set 13 | manta
# Processing Record 12 of Set 13 | barwadih
# Processing Record 13 of Set 13 | aswan
# Processing Record 14 of Set 13 | vestmannaeyjar
# Processing Record 15 of Set 13 | pingdingshan
# Processing Record 16 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 17 of Set 13 | hanzhong
# Processing Record 18 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 13 | north bend
# Processing Record 20 of Set 13 | zambezi
# Processing Record 21 of Set 13 | sobolevo
# Processing Record 22 of Set 13 | abalak
# Processing Record 23 of Set 13 | scottsbluff
# Processing Record 24 of Set 13 | hay river
# Processing Record 25 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 26 of Set 13 | kendari
# Processing Record 27 of Set 13 | lompoc
# Processing Record 28 of Set 13 | ancud
# Processing Record 29 of Set 13 | northam
# Processing Record 30 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 13 | merauke
# Processing Record 32 of Set 13 | kawalu
# Processing Record 33 of Set 13 | hidalgo
# Processing Record 34 of Set 13 | bedele
# Processing Record 35 of Set 13 | zhengjiatun
# Processing Record 36 of Set 13 | bitung
# Processing Record 37 of Set 13 | kibondo
# Processing Record 38 of Set 13 | petrozavodsk
# Processing Record 39 of Set 13 | roebourne
# Processing Record 40 of Set 13 | west lafayette
# Processing Record 41 of Set 13 | nisko
# Processing Record 42 of Set 13 | yeppoon
# Processing Record 43 of Set 13 | biak
# Processing Record 44 of Set 13 | ellsworth
# Processing Record 45 of Set 13 | orapa
# Processing Record 46 of Set 13 | sainte-marie
# Processing Record 47 of Set 13 | dharchula
# Processing Record 48 of Set 13 | baker city
# Processing Record 49 of Set 13 | khoy
# Processing Record 50 of Set 13 | penzance
# Processing Record 1 of Set 14 | port keats
# Processing Record 2 of Set 14 | lashio
# Processing Record 3 of Set 14 | jacareacanga
# Processing Record 4 of Set 14 | hobyo
# Processing Record 5 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 6 of Set 14 | porosozero
# Processing Record 7 of Set 14 | uray
# Processing Record 8 of Set 14 | namie
# Processing Record 9 of Set 14 | arganil
# Processing Record 10 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 14 | tabou
# Processing Record 12 of Set 14 | zhireken
# Processing Record 13 of Set 14 | teul
# City not found. Skipping...
# Processing Record 14 of Set 14 | kamenka
# Processing Record 15 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 14 | port macquarie
# Processing Record 17 of Set 14 | lida
# Processing Record 18 of Set 14 | leninskiy
# Processing Record 19 of Set 14 | simao
# Processing Record 20 of Set 14 | kismayo
# Processing Record 21 of Set 14 | chuzhou
# Processing Record 22 of Set 14 | dubai
# Processing Record 23 of Set 14 | watford
# Processing Record 24 of Set 14 | livingston
# Processing Record 25 of Set 14 | tura
# Processing Record 26 of Set 14 | marquette
# Processing Record 27 of Set 14 | bongaree
# Processing Record 28 of Set 14 | bajil
# Processing Record 29 of Set 14 | clacton-on-sea
# Processing Record 30 of Set 14 | sechura
# Processing Record 31 of Set 14 | guantanamo
# Processing Record 32 of Set 14 | sawakin
# Processing Record 33 of Set 14 | kahului
# Processing Record 34 of Set 14 | wanlaweyn
# Processing Record 35 of Set 14 | conde
# Processing Record 36 of Set 14 | zavodouspenskoye
# Processing Record 37 of Set 14 | ban nahin
# Processing Record 38 of Set 14 | wuwei
# Processing Record 39 of Set 14 | tenamaxtlan
# Processing Record 40 of Set 14 | kucevo
# Processing Record 41 of Set 14 | taman
# Processing Record 42 of Set 14 | come
# Processing Record 43 of Set 14 | andarab
# City not found. Skipping...
# Processing Record 44 of Set 14 | aitape
# Processing Record 45 of Set 14 | surt
# Processing Record 46 of Set 14 | kidal
# Processing Record 47 of Set 14 | chattanooga
# Processing Record 48 of Set 14 | nauta
# Processing Record 49 of Set 14 | nanyamba
# Processing Record 50 of Set 14 | najran
# Processing Record 1 of Set 15 | kimbe
# Processing Record 2 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 15 | ust-kuyga
# Processing Record 4 of Set 15 | bharatpur
# Processing Record 5 of Set 15 | mariental
# Processing Record 6 of Set 15 | karpathos
# Processing Record 7 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 8 of Set 15 | tyubuk
# Processing Record 9 of Set 15 | big rapids
# Processing Record 10 of Set 15 | nhamunda
# Processing Record 11 of Set 15 | betioky
# Processing Record 12 of Set 15 | san felipe
# Processing Record 13 of Set 15 | obihiro
# Processing Record 14 of Set 15 | ugoofaaru
# Processing Record 15 of Set 15 | kharan
# Processing Record 16 of Set 15 | calvinia
# Processing Record 17 of Set 15 | nosy varika
# Processing Record 18 of Set 15 | yerofey pavlovich
# Processing Record 19 of Set 15 | madanapalle
# Processing Record 20 of Set 15 | broome
# Processing Record 21 of Set 15 | achutupo
# Processing Record 22 of Set 15 | berlevag
# Processing Record 23 of Set 15 | sorland
# Processing Record 24 of Set 15 | ibia
# Processing Record 25 of Set 15 | casablanca
# Processing Record 26 of Set 15 | alto araguaia
# Processing Record 27 of Set 15 | minador do negrao
# Processing Record 28 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 29 of Set 15 | sur
# Processing Record 30 of Set 15 | san juan de los morros
# Processing Record 31 of Set 15 | zakharovo
# Processing Record 32 of Set 15 | khotynets
# Processing Record 33 of Set 15 | bathsheba
# Processing Record 34 of Set 15 | troitskoye
# Processing Record 35 of Set 15 | krasnoselkup
# Processing Record 36 of Set 15 | smidovich
# Processing Record 37 of Set 15 | nsanje
# Processing Record 38 of Set 15 | severobaykalsk
# Processing Record 39 of Set 15 | inuvik
# Processing Record 40 of Set 15 | sabha
# Processing Record 41 of Set 15 | dubbo
# Processing Record 42 of Set 15 | dwarka
# Processing Record 43 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 44 of Set 15 | mangrol
# Processing Record 45 of Set 15 | nalut
# Processing Record 46 of Set 15 | ca mau
# Processing Record 47 of Set 15 | nago
# Processing Record 48 of Set 15 | miranda
# Processing Record 49 of Set 15 | keokuk
# Processing Record 50 of Set 15 | lao cai
# Processing Record 1 of Set 16 | warrington
# Processing Record 2 of Set 16 | viedma
# Processing Record 3 of Set 16 | wenling
# Processing Record 4 of Set 16 | kholodnyy
# Processing Record 5 of Set 16 | russell
# Processing Record 6 of Set 16 | sisimiut
# Processing Record 7 of Set 16 | kavos
# Processing Record 8 of Set 16 | ballina
# Processing Record 9 of Set 16 | yunjinghong
# City not found. Skipping...
# Processing Record 10 of Set 16 | acajutla
# Processing Record 11 of Set 16 | juneau
# Processing Record 12 of Set 16 | atambua
# Processing Record 13 of Set 16 | custoias
# Processing Record 14 of Set 16 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 16 | himatangi
# Processing Record 16 of Set 16 | alpena
# Processing Record 17 of Set 16 | ormara
# Processing Record 18 of Set 16 | kasane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Tiksi  71.6872  128.8694     -9.65        97          51        3.67
# 1    Ostrovnoy  68.0531   39.5131     17.35        92         100       10.11
# 2       Albany  42.6001  -73.9662      6.75        57         100       18.01
# 3   San Rafael -34.6177  -68.3301     77.65        42          19        1.79
# 4  New Norfolk -42.7826  147.0587     81.66        31           0        1.99
# 5   Nikolskoye  59.7035   30.7861     27.72        93         100       15.68
# 6        Sitka  57.0531 -135.3300     35.49        87         100       11.50
# 7    Rudkobing  54.9364   10.7102     44.58        69          83       48.16
# 8    Kaohsiung  22.6163  120.3133     69.75        73          40        3.00
# 9     Thompson  55.7435  -97.8558    -14.64        76          75        0.00
#
#         Description Country                 Date
# 0     broken clouds      RU  2022-01-30 03:15:43
# 1        light snow      RU  2022-01-30 03:10:53
# 2   overcast clouds      US  2022-01-30 03:15:43
# 3        few clouds      AR  2022-01-30 03:15:43
# 4         clear sky      AU  2022-01-30 03:15:44
# 5              snow      RU  2022-01-30 03:15:44
# 6     moderate rain      US  2022-01-30 03:15:45
# 7     broken clouds      DK  2022-01-30 03:15:45
# 8  scattered clouds      TW  2022-01-30 03:15:45
# 9     broken clouds      CA  2022-01-30 03:15:46

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
export_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(export_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/s8/7__gkhq15530tygbs3rs01xm0000gn/T/ipykernel_4652/668613584.py in <module>
#       4
#       5 # Export the City_Data into a CSV.
# ----> 6 city_data_df.to_csv(export_file, index_label="City_ID")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
