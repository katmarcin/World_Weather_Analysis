# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
 #Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chuy
# Processing Record 2 of Set 1 | iquique
# Processing Record 3 of Set 1 | bontang
# Processing Record 4 of Set 1 | tuatapere
# Processing Record 5 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | galesong
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | anadyr
# Processing Record 10 of Set 1 | lavrentiya
# Processing Record 11 of Set 1 | taseyevo
# Processing Record 12 of Set 1 | lesnoye
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | vila franca do campo
# Processing Record 15 of Set 1 | touros
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | tabou
# Processing Record 27 of Set 1 | moroni
# Processing Record 28 of Set 1 | vao
# Processing Record 29 of Set 1 | osoyoos
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | arica
# Processing Record 32 of Set 1 | yuanping
# Processing Record 33 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 1 | katsuura
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | fort nelson
# Processing Record 37 of Set 1 | tirukkoyilur
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | dingle
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | birao
# Processing Record 44 of Set 1 | tangi
# Processing Record 45 of Set 1 | washougal
# Processing Record 46 of Set 1 | balimo
# City not found. Skipping...
# Processing Record 47 of Set 1 | carlsbad
# Processing Record 48 of Set 1 | makokou
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | paramonga
# Processing Record 2 of Set 2 | sobolevo
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | nome
# Processing Record 5 of Set 2 | cabo san lucas
# Processing Record 6 of Set 2 | machilipatnam
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | tamiahua
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | sexsmith
# Processing Record 16 of Set 2 | hamilton
# Processing Record 17 of Set 2 | sitka
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | labuhan
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | geraldton
# Processing Record 23 of Set 2 | molo
# Processing Record 24 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | effingham
# Processing Record 27 of Set 2 | xilitla
# Processing Record 28 of Set 2 | mazyr
# Processing Record 29 of Set 2 | hualmay
# Processing Record 30 of Set 2 | portland
# Processing Record 31 of Set 2 | gornopravdinsk
# Processing Record 32 of Set 2 | itarantim
# Processing Record 33 of Set 2 | kharagauli
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | hovin
# Processing Record 36 of Set 2 | manoel urbano
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | santa rosa
# Processing Record 39 of Set 2 | bogandinskiy
# Processing Record 40 of Set 2 | fonte boa
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | diego de almagro
# Processing Record 44 of Set 2 | peniche
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | kadnikov
# Processing Record 47 of Set 2 | haines junction
# Processing Record 48 of Set 2 | beira
# Processing Record 49 of Set 2 | gat
# Processing Record 50 of Set 2 | hofn
# Processing Record 1 of Set 3 | punta arenas
# Processing Record 2 of Set 3 | chinsali
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | port alfred
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | seoul
# Processing Record 7 of Set 3 | keelung
# Processing Record 8 of Set 3 | busselton
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | male
# Processing Record 11 of Set 3 | yar-sale
# Processing Record 12 of Set 3 | fortuna
# Processing Record 13 of Set 3 | monroe
# Processing Record 14 of Set 3 | sohag
# Processing Record 15 of Set 3 | valparaiso
# Processing Record 16 of Set 3 | ust-kut
# Processing Record 17 of Set 3 | asau
# Processing Record 18 of Set 3 | saint-pierre
# Processing Record 19 of Set 3 | parry sound
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | lithakia
# Processing Record 22 of Set 3 | henties bay
# Processing Record 23 of Set 3 | ukiah
# Processing Record 24 of Set 3 | nipawin
# Processing Record 25 of Set 3 | kerema
# Processing Record 26 of Set 3 | salalah
# Processing Record 27 of Set 3 | bluff
# Processing Record 28 of Set 3 | fraserburgh
# Processing Record 29 of Set 3 | lorengau
# Processing Record 30 of Set 3 | huanan
# Processing Record 31 of Set 3 | puerto suarez
# Processing Record 32 of Set 3 | mar del plata
# Processing Record 33 of Set 3 | hoquiam
# Processing Record 34 of Set 3 | dutlwe
# Processing Record 35 of Set 3 | corrente
# Processing Record 36 of Set 3 | gasa
# Processing Record 37 of Set 3 | pali
# Processing Record 38 of Set 3 | port lincoln
# Processing Record 39 of Set 3 | hithadhoo
# Processing Record 40 of Set 3 | cockburn town
# Processing Record 41 of Set 3 | grand gaube
# Processing Record 42 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 3 | saint george
# Processing Record 44 of Set 3 | quelimane
# Processing Record 45 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 3 | holoby
# Processing Record 47 of Set 3 | duluth
# Processing Record 48 of Set 3 | aromashevo
# Processing Record 49 of Set 3 | madison heights
# Processing Record 50 of Set 3 | liberal
# Processing Record 1 of Set 4 | miechow
# Processing Record 2 of Set 4 | duzce
# Processing Record 3 of Set 4 | kucura
# Processing Record 4 of Set 4 | kingman
# Processing Record 5 of Set 4 | gua musang
# Processing Record 6 of Set 4 | baraki barak
# Processing Record 7 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 4 | brae
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | nefteyugansk
# Processing Record 11 of Set 4 | igarka
# Processing Record 12 of Set 4 | todos santos
# Processing Record 13 of Set 4 | maragogi
# Processing Record 14 of Set 4 | belmonte
# Processing Record 15 of Set 4 | tucuma
# Processing Record 16 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 4 | burns lake
# Processing Record 18 of Set 4 | bambous virieux
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | gizo
# Processing Record 21 of Set 4 | caucaia
# Processing Record 22 of Set 4 | kavaratti
# Processing Record 23 of Set 4 | macherla
# Processing Record 24 of Set 4 | itoman
# Processing Record 25 of Set 4 | atuona
# Processing Record 26 of Set 4 | hobart
# Processing Record 27 of Set 4 | sao miguel do araguaia
# Processing Record 28 of Set 4 | naryan-mar
# Processing Record 29 of Set 4 | rocha
# Processing Record 30 of Set 4 | dombarovskiy
# Processing Record 31 of Set 4 | benghazi
# Processing Record 32 of Set 4 | cheremukhovo
# Processing Record 33 of Set 4 | korla
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | butaritari
# Processing Record 36 of Set 4 | gazanjyk
# Processing Record 37 of Set 4 | wasilla
# Processing Record 38 of Set 4 | constantine
# Processing Record 39 of Set 4 | clyde river
# Processing Record 40 of Set 4 | medicine hat
# Processing Record 41 of Set 4 | wajima
# Processing Record 42 of Set 4 | monrovia
# Processing Record 43 of Set 4 | bilibino
# Processing Record 44 of Set 4 | mujiayingzi
# Processing Record 45 of Set 4 | kushmurun
# Processing Record 46 of Set 4 | ponta do sol
# Processing Record 47 of Set 4 | pangnirtung
# Processing Record 48 of Set 4 | borogontsy
# Processing Record 49 of Set 4 | kachug
# Processing Record 50 of Set 4 | opuwo
# Processing Record 1 of Set 5 | cumpas
# Processing Record 2 of Set 5 | shubarkuduk
# Processing Record 3 of Set 5 | riyadh
# Processing Record 4 of Set 5 | sapele
# Processing Record 5 of Set 5 | boda
# Processing Record 6 of Set 5 | torbay
# Processing Record 7 of Set 5 | singleton
# Processing Record 8 of Set 5 | ulenje
# Processing Record 9 of Set 5 | leningradskiy
# Processing Record 10 of Set 5 | stornoway
# Processing Record 11 of Set 5 | yurimaguas
# Processing Record 12 of Set 5 | zeya
# Processing Record 13 of Set 5 | kaitangata
# Processing Record 14 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 5 | berlevag
# Processing Record 16 of Set 5 | samarkand
# Processing Record 17 of Set 5 | toamasina
# Processing Record 18 of Set 5 | marienburg
# Processing Record 19 of Set 5 | luderitz
# Processing Record 20 of Set 5 | coos bay
# Processing Record 21 of Set 5 | risor
# Processing Record 22 of Set 5 | praia
# Processing Record 23 of Set 5 | zyryanka
# Processing Record 24 of Set 5 | nouadhibou
# Processing Record 25 of Set 5 | mahajanga
# Processing Record 26 of Set 5 | zhigansk
# Processing Record 27 of Set 5 | ha tinh
# Processing Record 28 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 5 | moose factory
# Processing Record 30 of Set 5 | san buenaventura
# Processing Record 31 of Set 5 | trelew
# Processing Record 32 of Set 5 | banyo
# Processing Record 33 of Set 5 | ladario
# Processing Record 34 of Set 5 | kruisfontein
# Processing Record 35 of Set 5 | richards bay
# Processing Record 36 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 5 | cherskiy
# Processing Record 38 of Set 5 | filadelfia
# Processing Record 39 of Set 5 | severo-kurilsk
# Processing Record 40 of Set 5 | leshukonskoye
# Processing Record 41 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 5 | serenje
# Processing Record 43 of Set 5 | lumeje
# Processing Record 44 of Set 5 | hobyo
# Processing Record 45 of Set 5 | broome
# Processing Record 46 of Set 5 | prince rupert
# Processing Record 47 of Set 5 | chaman
# Processing Record 48 of Set 5 | harper
# Processing Record 49 of Set 5 | yaan
# Processing Record 50 of Set 5 | chino valley
# Processing Record 1 of Set 6 | mackenzie
# Processing Record 2 of Set 6 | tapejara
# Processing Record 3 of Set 6 | coffs harbour
# Processing Record 4 of Set 6 | mackay
# Processing Record 5 of Set 6 | georgetown
# Processing Record 6 of Set 6 | victoria
# Processing Record 7 of Set 6 | tongliao
# Processing Record 8 of Set 6 | ostrovnoy
# Processing Record 9 of Set 6 | lucea
# Processing Record 10 of Set 6 | eyl
# Processing Record 11 of Set 6 | eirunepe
# Processing Record 12 of Set 6 | norman wells
# Processing Record 13 of Set 6 | provideniya
# Processing Record 14 of Set 6 | mount isa
# Processing Record 15 of Set 6 | neuquen
# Processing Record 16 of Set 6 | dukat
# Processing Record 17 of Set 6 | jabinyanah
# Processing Record 18 of Set 6 | pemberton
# Processing Record 19 of Set 6 | camacha
# Processing Record 20 of Set 6 | itarema
# Processing Record 21 of Set 6 | san quintin
# Processing Record 22 of Set 6 | northam
# Processing Record 23 of Set 6 | poum
# Processing Record 24 of Set 6 | nara
# Processing Record 25 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 6 | drumheller
# Processing Record 27 of Set 6 | phan thiet
# Processing Record 28 of Set 6 | lagoa santa
# Processing Record 29 of Set 6 | sinnamary
# Processing Record 30 of Set 6 | friedeburg
# Processing Record 31 of Set 6 | tiksi
# Processing Record 32 of Set 6 | graaff-reinet
# Processing Record 33 of Set 6 | klerksdorp
# Processing Record 34 of Set 6 | mahebourg
# Processing Record 35 of Set 6 | parana
# Processing Record 36 of Set 6 | saint-francois
# Processing Record 37 of Set 6 | kayes
# Processing Record 38 of Set 6 | ayr
# Processing Record 39 of Set 6 | kununurra
# Processing Record 40 of Set 6 | coquimbo
# Processing Record 41 of Set 6 | vostok
# Processing Record 42 of Set 6 | puerto colombia
# Processing Record 43 of Set 6 | lagoa
# Processing Record 44 of Set 6 | lebu
# Processing Record 45 of Set 6 | lucapa
# Processing Record 46 of Set 6 | hay river
# Processing Record 47 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 48 of Set 6 | phuket
# Processing Record 49 of Set 6 | redcar
# Processing Record 50 of Set 6 | narsaq
# Processing Record 1 of Set 7 | quatre cocos
# Processing Record 2 of Set 7 | colares
# Processing Record 3 of Set 7 | bac lieu
# Processing Record 4 of Set 7 | west bay
# Processing Record 5 of Set 7 | dungarpur
# Processing Record 6 of Set 7 | guatavita
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 7 | lazaro cardenas
# Processing Record 11 of Set 7 | nemuro
# Processing Record 12 of Set 7 | finschhafen
# Processing Record 13 of Set 7 | avera
# Processing Record 14 of Set 7 | klaksvik
# Processing Record 15 of Set 7 | margate
# Processing Record 16 of Set 7 | talnakh
# Processing Record 17 of Set 7 | alofi
# Processing Record 18 of Set 7 | thompson
# Processing Record 19 of Set 7 | san juan
# Processing Record 20 of Set 7 | porto novo
# Processing Record 21 of Set 7 | port macquarie
# Processing Record 22 of Set 7 | nishihara
# Processing Record 23 of Set 7 | raudeberg
# Processing Record 24 of Set 7 | florianopolis
# Processing Record 25 of Set 7 | podyuga
# Processing Record 26 of Set 7 | verkhnevilyuysk
# Processing Record 27 of Set 7 | yulara
# Processing Record 28 of Set 7 | birjand
# Processing Record 29 of Set 7 | sistranda
# Processing Record 30 of Set 7 | arbagar
# Processing Record 31 of Set 7 | sao filipe
# Processing Record 32 of Set 7 | batasan
# Processing Record 33 of Set 7 | pinega
# Processing Record 34 of Set 7 | ancud
# Processing Record 35 of Set 7 | sur
# Processing Record 36 of Set 7 | chongwe
# Processing Record 37 of Set 7 | kisoro
# Processing Record 38 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 7 | vardo
# Processing Record 40 of Set 7 | paamiut
# Processing Record 41 of Set 7 | havre-saint-pierre
# Processing Record 42 of Set 7 | daru
# Processing Record 43 of Set 7 | calatayud
# Processing Record 44 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | guerrero negro
# Processing Record 46 of Set 7 | jalu
# Processing Record 47 of Set 7 | brigantine
# Processing Record 48 of Set 7 | kamenka
# Processing Record 49 of Set 7 | seminole
# Processing Record 50 of Set 7 | wewak
# Processing Record 1 of Set 8 | creston
# Processing Record 2 of Set 8 | laguna
# Processing Record 3 of Set 8 | manzil salim
# Processing Record 4 of Set 8 | la serena
# Processing Record 5 of Set 8 | la ronge
# Processing Record 6 of Set 8 | pandan
# Processing Record 7 of Set 8 | hambantota
# Processing Record 8 of Set 8 | puerto escondido
# Processing Record 9 of Set 8 | kisangani
# Processing Record 10 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 11 of Set 8 | balikpapan
# Processing Record 12 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 8 | altay
# Processing Record 14 of Set 8 | sao joao da barra
# Processing Record 15 of Set 8 | bundaberg
# Processing Record 16 of Set 8 | kencong
# Processing Record 17 of Set 8 | sandwick
# Processing Record 18 of Set 8 | garden city
# Processing Record 19 of Set 8 | lompoc
# Processing Record 20 of Set 8 | zadar
# Processing Record 21 of Set 8 | kulhudhuffushi
# Processing Record 22 of Set 8 | aksarka
# Processing Record 23 of Set 8 | sept-iles
# Processing Record 24 of Set 8 | mangai
# Processing Record 25 of Set 8 | banda aceh
# Processing Record 26 of Set 8 | wadi musa
# Processing Record 27 of Set 8 | santa maria
# Processing Record 28 of Set 8 | quimper
# Processing Record 29 of Set 8 | timra
# Processing Record 30 of Set 8 | stettler
# Processing Record 31 of Set 8 | namibe
# Processing Record 32 of Set 8 | airai
# Processing Record 33 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 8 | flinders
# Processing Record 35 of Set 8 | malente
# Processing Record 36 of Set 8 | abu zabad
# Processing Record 37 of Set 8 | svetlogorsk
# Processing Record 38 of Set 8 | nizwa
# Processing Record 39 of Set 8 | grindavik
# Processing Record 40 of Set 8 | axim
# Processing Record 41 of Set 8 | novikovo
# Processing Record 42 of Set 8 | husavik
# Processing Record 43 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 8 | saldanha
# Processing Record 45 of Set 8 | talas
# Processing Record 46 of Set 8 | karratha
# Processing Record 47 of Set 8 | coihaique
# Processing Record 48 of Set 8 | waingapu
# Processing Record 49 of Set 8 | maku
# Processing Record 50 of Set 8 | pauini
# Processing Record 1 of Set 9 | constitucion
# Processing Record 2 of Set 9 | meulaboh
# Processing Record 3 of Set 9 | borama
# City not found. Skipping...
# Processing Record 4 of Set 9 | tolaga bay
# Processing Record 5 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 6 of Set 9 | nisia floresta
# Processing Record 7 of Set 9 | sheridan
# Processing Record 8 of Set 9 | pisco
# Processing Record 9 of Set 9 | colon
# Processing Record 10 of Set 9 | nam tha
# City not found. Skipping...
# Processing Record 11 of Set 9 | rawson
# Processing Record 12 of Set 9 | anloga
# Processing Record 13 of Set 9 | pacific grove
# Processing Record 14 of Set 9 | saint-augustin
# Processing Record 15 of Set 9 | naifaru
# Processing Record 16 of Set 9 | diamantino
# Processing Record 17 of Set 9 | danilovka
# Processing Record 18 of Set 9 | kaputa
# Processing Record 19 of Set 9 | santiago del estero
# Processing Record 20 of Set 9 | lodi
# Processing Record 21 of Set 9 | longyearbyen
# Processing Record 22 of Set 9 | nova granada
# Processing Record 23 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 9 | amantea
# Processing Record 25 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 9 | balkanabat
# Processing Record 27 of Set 9 | goroka
# Processing Record 28 of Set 9 | ahipara
# Processing Record 29 of Set 9 | veraval
# Processing Record 30 of Set 9 | malindi
# Processing Record 31 of Set 9 | komsomolskiy
# Processing Record 32 of Set 9 | simbahan
# Processing Record 33 of Set 9 | sri aman
# Processing Record 34 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 35 of Set 9 | codrington
# Processing Record 36 of Set 9 | worland
# Processing Record 37 of Set 9 | camacupa
# Processing Record 38 of Set 9 | alice springs
# Processing Record 39 of Set 9 | zheleznodorozhnyy
# Processing Record 40 of Set 9 | ilulissat
# Processing Record 41 of Set 9 | oshnaviyeh
# Processing Record 42 of Set 9 | tanete
# Processing Record 43 of Set 9 | camopi
# Processing Record 44 of Set 9 | oranjemund
# Processing Record 45 of Set 9 | agua verde
# Processing Record 46 of Set 9 | dzaoudzi
# Processing Record 47 of Set 9 | zaysan
# Processing Record 48 of Set 9 | la macarena
# Processing Record 49 of Set 9 | srednekolymsk
# Processing Record 50 of Set 9 | conde
# Processing Record 1 of Set 10 | havoysund
# Processing Record 2 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 3 of Set 10 | dunedin
# Processing Record 4 of Set 10 | pamanukan
# Processing Record 5 of Set 10 | tazovskiy
# Processing Record 6 of Set 10 | sangar
# Processing Record 7 of Set 10 | taoudenni
# Processing Record 8 of Set 10 | orlik
# Processing Record 9 of Set 10 | sokolo
# Processing Record 10 of Set 10 | teseney
# Processing Record 11 of Set 10 | robat karim
# Processing Record 12 of Set 10 | balarampur
# Processing Record 13 of Set 10 | umm lajj
# Processing Record 14 of Set 10 | maningrida
# Processing Record 15 of Set 10 | vila velha
# Processing Record 16 of Set 10 | kahului
# Processing Record 17 of Set 10 | burica
# City not found. Skipping...
# Processing Record 18 of Set 10 | mount pleasant
# Processing Record 19 of Set 10 | jingdezhen
# Processing Record 20 of Set 10 | zwedru
# Processing Record 21 of Set 10 | fallon
# Processing Record 22 of Set 10 | tiznit
# Processing Record 23 of Set 10 | padang
# Processing Record 24 of Set 10 | paita
# Processing Record 25 of Set 10 | saint-georges
# Processing Record 26 of Set 10 | chicama
# Processing Record 27 of Set 10 | jishu
# Processing Record 28 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 10 | yakeshi
# Processing Record 30 of Set 10 | talitsy
# Processing Record 31 of Set 10 | am timan
# Processing Record 32 of Set 10 | beysehir
# Processing Record 33 of Set 10 | mantua
# Processing Record 34 of Set 10 | budisov nad budisovkou
# Processing Record 35 of Set 10 | iqaluit
# Processing Record 36 of Set 10 | bonthe
# Processing Record 37 of Set 10 | lamu
# Processing Record 38 of Set 10 | kudat
# Processing Record 39 of Set 10 | shirokiy
# Processing Record 40 of Set 10 | savinka
# Processing Record 41 of Set 10 | yuksekova
# Processing Record 42 of Set 10 | minot
# Processing Record 43 of Set 10 | hovd
# Processing Record 44 of Set 10 | shache
# Processing Record 45 of Set 10 | safakulevo
# Processing Record 46 of Set 10 | amarante do maranhao
# Processing Record 47 of Set 10 | viedma
# Processing Record 48 of Set 10 | naze
# Processing Record 49 of Set 10 | ramsar
# Processing Record 50 of Set 10 | adrar
# Processing Record 1 of Set 11 | zverinogolovskoye
# Processing Record 2 of Set 11 | olafsvik
# Processing Record 3 of Set 11 | falam
# Processing Record 4 of Set 11 | manggar
# Processing Record 5 of Set 11 | batagay-alyta
# Processing Record 6 of Set 11 | college
# Processing Record 7 of Set 11 | dubbo
# Processing Record 8 of Set 11 | isangel
# Processing Record 9 of Set 11 | inndyr
# Processing Record 10 of Set 11 | pakokku
# Processing Record 11 of Set 11 | dedza
# Processing Record 12 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 11 | kevsala
# Processing Record 14 of Set 11 | astipalaia
# City not found. Skipping...
# Processing Record 15 of Set 11 | bud
# Processing Record 16 of Set 11 | batemans bay
# Processing Record 17 of Set 11 | kijang
# Processing Record 18 of Set 11 | key west
# Processing Record 19 of Set 11 | san pedro
# Processing Record 20 of Set 11 | hervey bay
# Processing Record 21 of Set 11 | ayan
# Processing Record 22 of Set 11 | ereymentau
# Processing Record 23 of Set 11 | galle
# Processing Record 24 of Set 11 | wagga wagga
# Processing Record 25 of Set 11 | port-cartier
# Processing Record 26 of Set 11 | chandla
# Processing Record 27 of Set 11 | nanuque
# Processing Record 28 of Set 11 | tomatlan
# Processing Record 29 of Set 11 | damghan
# Processing Record 30 of Set 11 | ambulu
# Processing Record 31 of Set 11 | santa cruz de tenerife
# Processing Record 32 of Set 11 | arlit
# Processing Record 33 of Set 11 | los llanos de aridane
# Processing Record 34 of Set 11 | almaznyy
# Processing Record 35 of Set 11 | dubovskoye
# Processing Record 36 of Set 11 | upington
# Processing Record 37 of Set 11 | himora
# City not found. Skipping...
# Processing Record 38 of Set 11 | havelock
# Processing Record 39 of Set 11 | muroto
# Processing Record 40 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 11 | bend
# Processing Record 42 of Set 11 | lubaczow
# Processing Record 43 of Set 11 | golfito
# Processing Record 44 of Set 11 | thanh hoa
# Processing Record 45 of Set 11 | palau
# Processing Record 46 of Set 11 | honiara
# Processing Record 47 of Set 11 | beberibe
# Processing Record 48 of Set 11 | telixtlahuaca
# City not found. Skipping...
# Processing Record 49 of Set 11 | bairiki
# Processing Record 50 of Set 11 | povenets
# Processing Record 1 of Set 12 | kungurtug
# Processing Record 2 of Set 12 | pochutla
# Processing Record 3 of Set 12 | myra
# Processing Record 4 of Set 12 | abu dhabi
# Processing Record 5 of Set 12 | gamba
# Processing Record 6 of Set 12 | sisimiut
# Processing Record 7 of Set 12 | sao felix do xingu
# Processing Record 8 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 12 | houma
# Processing Record 10 of Set 12 | san patricio
# Processing Record 11 of Set 12 | redlands
# Processing Record 12 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 12 | puerto del rosario
# Processing Record 14 of Set 12 | saint anthony
# Processing Record 15 of Set 12 | te anau
# Processing Record 16 of Set 12 | tura
# Processing Record 17 of Set 12 | mora
# Processing Record 18 of Set 12 | cap malheureux
# Processing Record 19 of Set 12 | wembley
# Processing Record 20 of Set 12 | sergeyevka
# Processing Record 21 of Set 12 | fenoarivo
# Processing Record 22 of Set 12 | kuala terengganu
# Processing Record 23 of Set 12 | ponta delgada
# Processing Record 24 of Set 12 | ormara
# Processing Record 25 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 26 of Set 12 | biak
# Processing Record 27 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 12 | hvolsvollur
# Processing Record 29 of Set 12 | bolshaya sosnova
# Processing Record 30 of Set 12 | palmer
# Processing Record 31 of Set 12 | katobu
# Processing Record 32 of Set 12 | newcastle
# Processing Record 33 of Set 12 | pinheiro machado
# Processing Record 34 of Set 12 | agirish
# Processing Record 35 of Set 12 | ishinomaki
# Processing Record 36 of Set 12 | sungaipenuh
# Processing Record 37 of Set 12 | lima
# Processing Record 38 of Set 12 | fez
# Processing Record 39 of Set 12 | bumba
# Processing Record 40 of Set 12 | doka
# Processing Record 41 of Set 12 | michalovce
# Processing Record 42 of Set 12 | port keats
# Processing Record 43 of Set 12 | itapora
# Processing Record 44 of Set 12 | munster
# Processing Record 45 of Set 12 | mahibadhoo
# Processing Record 46 of Set 12 | maseru
# Processing Record 47 of Set 12 | agadez
# Processing Record 48 of Set 12 | inhambane
# Processing Record 49 of Set 12 | basco
# Processing Record 50 of Set 12 | amarastii de jos
# Processing Record 1 of Set 13 | souillac
# Processing Record 2 of Set 13 | chimbote
# Processing Record 3 of Set 13 | vilhena
# Processing Record 4 of Set 13 | okahandja
# Processing Record 5 of Set 13 | san antero
# Processing Record 6 of Set 13 | kudahuvadhoo
# Processing Record 7 of Set 13 | otradnoye
# Processing Record 8 of Set 13 | le port
# Processing Record 9 of Set 13 | ginir
# Processing Record 10 of Set 13 | delitzsch
# Processing Record 11 of Set 13 | namuac
# Processing Record 12 of Set 13 | ardakan
# Processing Record 13 of Set 13 | sioux lookout
# Processing Record 14 of Set 13 | sao jose da coroa grande
# Processing Record 15 of Set 13 | ndioum
# Processing Record 16 of Set 13 | port hardy
# Processing Record 17 of Set 13 | shu
# Processing Record 18 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 19 of Set 13 | shelopugino
# Processing Record 20 of Set 13 | port-gentil
# Processing Record 21 of Set 13 | kapiri mposhi
# Processing Record 22 of Set 13 | ahuimanu
# Processing Record 23 of Set 13 | imisli
# City not found. Skipping...
# Processing Record 24 of Set 13 | korba
# Processing Record 25 of Set 13 | maputo
# Processing Record 26 of Set 13 | turukhansk
# Processing Record 27 of Set 13 | bandarbeyla
# Processing Record 28 of Set 13 | general roca
# Processing Record 29 of Set 13 | astoria
# Processing Record 30 of Set 13 | caravelas
# Processing Record 31 of Set 13 | nanortalik
# Processing Record 32 of Set 13 | half moon bay
# Processing Record 33 of Set 13 | vineland
# Processing Record 34 of Set 13 | stokmarknes
# Processing Record 35 of Set 13 | natal
# Processing Record 36 of Set 13 | oussouye
# Processing Record 37 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 13 | bani
# Processing Record 39 of Set 13 | aitape
# Processing Record 40 of Set 13 | guane
# Processing Record 41 of Set 13 | xining
# Processing Record 42 of Set 13 | katrineholm
# Processing Record 43 of Set 13 | cuiluan
# Processing Record 44 of Set 13 | kiunga
# Processing Record 45 of Set 13 | jacareacanga
# Processing Record 46 of Set 13 | stromness
# Processing Record 47 of Set 13 | praia da vitoria
# Processing Record 48 of Set 13 | livingston
# Processing Record 49 of Set 13 | lockhart
# Processing Record 50 of Set 13 | kholodnyy
# Processing Record 1 of Set 14 | kaseda
# Processing Record 2 of Set 14 | bombay
# Processing Record 3 of Set 14 | lukovetskiy
# Processing Record 4 of Set 14 | sinop
# Processing Record 5 of Set 14 | miraflores
# Processing Record 6 of Set 14 | acaponeta
# Processing Record 7 of Set 14 | farah
# Processing Record 8 of Set 14 | takoradi
# Processing Record 9 of Set 14 | tabas
# Processing Record 10 of Set 14 | tuy hoa
# Processing Record 11 of Set 14 | charlestown
# Processing Record 12 of Set 14 | khasan
# Processing Record 13 of Set 14 | gobindpur
# Processing Record 14 of Set 14 | visby
# Processing Record 15 of Set 14 | grafton
# Processing Record 16 of Set 14 | khalkhal
# Processing Record 17 of Set 14 | kurayoshi
# Processing Record 18 of Set 14 | moron
# Processing Record 19 of Set 14 | linxia
# Processing Record 20 of Set 14 | nakamura
# Processing Record 21 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 14 | prachuap khiri khan
# Processing Record 23 of Set 14 | suntar
# Processing Record 24 of Set 14 | hasaki
# Processing Record 25 of Set 14 | morgan city
# Processing Record 26 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 14 | cayenne
# Processing Record 28 of Set 14 | hailar
# Processing Record 29 of Set 14 | chirongui
# Processing Record 30 of Set 14 | nsunga
# Processing Record 31 of Set 14 | sinjar
# Processing Record 32 of Set 14 | waitati
# Processing Record 33 of Set 14 | bay roberts
# Processing Record 34 of Set 14 | namatanai
# Processing Record 35 of Set 14 | hakvik
# City not found. Skipping...
# Processing Record 36 of Set 14 | zemio
# Processing Record 37 of Set 14 | oyek
# Processing Record 38 of Set 14 | wamba
# Processing Record 39 of Set 14 | zirandaro
# Processing Record 40 of Set 14 | merauke
# Processing Record 41 of Set 14 | serik
# Processing Record 42 of Set 14 | kieta
# Processing Record 43 of Set 14 | sosva
# Processing Record 44 of Set 14 | san francisco del mar
# Processing Record 45 of Set 14 | bubaque
# Processing Record 46 of Set 14 | oistins
# Processing Record 47 of Set 14 | pahrump
# Processing Record 48 of Set 14 | zhangjiakou
# Processing Record 49 of Set 14 | karpenision
# City not found. Skipping...
# Processing Record 50 of Set 14 | umm kaddadah
# Processing Record 1 of Set 15 | portpatrick
# City not found. Skipping...
# Processing Record 2 of Set 15 | pringsewu
# Processing Record 3 of Set 15 | batsfjord
# Processing Record 4 of Set 15 | huilong
# Processing Record 5 of Set 15 | carmarthen
# Processing Record 6 of Set 15 | banjar
# Processing Record 7 of Set 15 | bonavista
# Processing Record 8 of Set 15 | pooler
# Processing Record 9 of Set 15 | kuytun
# Processing Record 10 of Set 15 | udachnyy
# Processing Record 11 of Set 15 | sarahan
# Processing Record 12 of Set 15 | erzin
# Processing Record 13 of Set 15 | rehli
# Processing Record 14 of Set 15 | suez
# Processing Record 15 of Set 15 | vilyuysk
# Processing Record 16 of Set 15 | shelburne
# Processing Record 17 of Set 15 | inta
# Processing Record 18 of Set 15 | buchanan
# Processing Record 19 of Set 15 | tilichiki
# Processing Record 20 of Set 15 | suhbaatar
# Processing Record 21 of Set 15 | rio grande
# Processing Record 22 of Set 15 | yumen
# Processing Record 23 of Set 15 | tessalit
# Processing Record 24 of Set 15 | lodja
# Processing Record 25 of Set 15 | baykit
# Processing Record 26 of Set 15 | hami
# Processing Record 27 of Set 15 | leh
# Processing Record 28 of Set 15 | may pen
# Processing Record 29 of Set 15 | sibolga
# Processing Record 30 of Set 15 | san luis
# Processing Record 31 of Set 15 | gigmoto
# Processing Record 32 of Set 15 | thyboron
# Processing Record 33 of Set 15 | rio gallegos
# Processing Record 34 of Set 15 | figeac
# Processing Record 35 of Set 15 | kaspiyskiy
# Processing Record 36 of Set 15 | ulladulla
# Processing Record 37 of Set 15 | maldonado
# Processing Record 38 of Set 15 | minuwangoda
# Processing Record 39 of Set 15 | ust-maya
# Processing Record 40 of Set 15 | san jose
# Processing Record 41 of Set 15 | san vicente
# Processing Record 42 of Set 15 | la cruz
# Processing Record 43 of Set 15 | nelson bay
# Processing Record 44 of Set 15 | hurghada
# Processing Record 45 of Set 15 | rolla
# Processing Record 46 of Set 15 | aracruz
# Processing Record 47 of Set 15 | soyo
# Processing Record 48 of Set 15 | gbarnga
# Processing Record 49 of Set 15 | kapit
# Processing Record 50 of Set 15 | payakumbuh
# Processing Record 1 of Set 16 | karamken
# City not found. Skipping...
# Processing Record 2 of Set 16 | capreol
# Processing Record 3 of Set 16 | san cristobal
# Processing Record 4 of Set 16 | inuvik
# Processing Record 5 of Set 16 | roald
# Processing Record 6 of Set 16 | solnechnyy
# Processing Record 7 of Set 16 | plouzane
# Processing Record 8 of Set 16 | santa cruz
# Processing Record 9 of Set 16 | najran
# Processing Record 10 of Set 16 | nioro
# Processing Record 11 of Set 16 | ust-uda
# Processing Record 12 of Set 16 | yialos
# City not found. Skipping...
# Processing Record 13 of Set 16 | kikwit
# Processing Record 14 of Set 16 | gananoque
# Processing Record 15 of Set 16 | melioratorov
# Processing Record 16 of Set 16 | lodingen
# Processing Record 17 of Set 16 | mercedes
# Processing Record 18 of Set 16 | kirakira
# Processing Record 19 of Set 16 | haldibari
# Processing Record 20 of Set 16 | comodoro rivadavia
# Processing Record 21 of Set 16 | xuddur
# Processing Record 22 of Set 16 | jizan
# Processing Record 23 of Set 16 | ndele
# Processing Record 24 of Set 16 | grand-santi
# Processing Record 25 of Set 16 | burnie
# Processing Record 26 of Set 16 | sambava
# Processing Record 27 of Set 16 | teya
# Processing Record 28 of Set 16 | goderich
# Processing Record 29 of Set 16 | pampierstad
# Processing Record 30 of Set 16 | atar
# Processing Record 31 of Set 16 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 16 | muros
# Processing Record 33 of Set 16 | selizharovo
# Processing Record 34 of Set 16 | fontem
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Chuy -33.6971  -53.4616     78.76        53          73       12.86
# 1     Iquique -20.2208  -70.1431     70.03        67           1        3.83
# 2     Bontang   0.1333  117.5000     78.13        85         100        5.17
# 3   Tuatapere -46.1333  167.6833     58.82        92          10        2.19
# 4     Qaanaaq  77.4840  -69.3632     -6.21        67         100        9.66
# 5    Galesong  -5.3166  119.3661     77.02        77         100        7.09
# 6    Hermanus -34.4187   19.2345     71.80        77         100       15.35
# 7      Anadyr  64.7500  177.4833    -19.52        82          75        2.24
# 8  Lavrentiya  65.5833 -171.0000     -5.12        89           3        5.10
# 9    Taseyevo  57.2169   94.8978     -6.05       100          99        1.43
#
#        Description Country                 Date
# 0    broken clouds      UY  2022-01-30 18:37:09
# 1        clear sky      CL  2022-01-30 18:37:10
# 2  overcast clouds      ID  2022-01-30 18:37:10
# 3        clear sky      NZ  2022-01-30 18:37:11
# 4  overcast clouds      GL  2022-01-30 18:37:11
# 5       light rain      ID  2022-01-30 18:37:11
# 6  overcast clouds      ZA  2022-01-30 18:37:11
# 7             mist      RU  2022-01-30 18:37:12
# 8        clear sky      RU  2022-01-30 18:37:12
# 9  overcast clouds      RU  2022-01-30 18:37:12

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
export_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(export_file, index_label="City_ID")
