# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
 #Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | lagos
# Processing Record 6 of Set 1 | palana
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | azuaga
# Processing Record 9 of Set 1 | coquimbo
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | hlotse
# Processing Record 16 of Set 1 | pinyug
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | longyan
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 1 | touros
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | evans
# Processing Record 25 of Set 1 | tumaco
# Processing Record 26 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 1 | marsh harbour
# Processing Record 28 of Set 1 | gao
# Processing Record 29 of Set 1 | eucaliptus
# Processing Record 30 of Set 1 | mkushi
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | mancio lima
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | staveley
# Processing Record 39 of Set 1 | tura
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | marienburg
# Processing Record 42 of Set 1 | codrington
# Processing Record 43 of Set 1 | manaus
# Processing Record 44 of Set 1 | longyearbyen
# Processing Record 45 of Set 1 | kahului
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | pokhara
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | ambilobe
# Processing Record 1 of Set 2 | guerrero negro
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | san pedro de los naranjos
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | kakamega
# Processing Record 6 of Set 2 | luganville
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 2 | krasnoarmeyskiy
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | brigantine
# Processing Record 12 of Set 2 | palmas
# Processing Record 13 of Set 2 | bambanglipuro
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | guekedou
# City not found. Skipping...
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | hay river
# Processing Record 20 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 2 | svetlogorsk
# Processing Record 22 of Set 2 | asau
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | moyale
# Processing Record 25 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 2 | gogrial
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | high rock
# Processing Record 29 of Set 2 | kruisfontein
# Processing Record 30 of Set 2 | fort nelson
# Processing Record 31 of Set 2 | avera
# Processing Record 32 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 2 | grand gaube
# Processing Record 34 of Set 2 | porto novo
# Processing Record 35 of Set 2 | tucurui
# Processing Record 36 of Set 2 | srednekolymsk
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | acari
# Processing Record 40 of Set 2 | fare
# Processing Record 41 of Set 2 | hamilton
# Processing Record 42 of Set 2 | tucuman
# Processing Record 43 of Set 2 | port hardy
# Processing Record 44 of Set 2 | puebloviejo
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | husavik
# Processing Record 47 of Set 2 | juneau
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | macklin
# Processing Record 50 of Set 2 | payakumbuh
# Processing Record 1 of Set 3 | pisco
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | edd
# Processing Record 8 of Set 3 | moroni
# Processing Record 9 of Set 3 | gurupa
# Processing Record 10 of Set 3 | katete
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | nurota
# Processing Record 13 of Set 3 | pamekasan
# Processing Record 14 of Set 3 | thunder bay
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | dingle
# Processing Record 17 of Set 3 | lat yao
# Processing Record 18 of Set 3 | iranshahr
# Processing Record 19 of Set 3 | souillac
# Processing Record 20 of Set 3 | barkhan
# Processing Record 21 of Set 3 | lasa
# Processing Record 22 of Set 3 | cherskiy
# Processing Record 23 of Set 3 | ornskoldsvik
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | gazanjyk
# Processing Record 26 of Set 3 | tiznit
# Processing Record 27 of Set 3 | bayan
# Processing Record 28 of Set 3 | sitka
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | saskylakh
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | hobyo
# Processing Record 33 of Set 3 | ilulissat
# Processing Record 34 of Set 3 | wawa
# Processing Record 35 of Set 3 | noumea
# Processing Record 36 of Set 3 | norman wells
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | san borja
# Processing Record 39 of Set 3 | marfino
# Processing Record 40 of Set 3 | mwanza
# Processing Record 41 of Set 3 | mount gambier
# Processing Record 42 of Set 3 | samarai
# Processing Record 43 of Set 3 | sibolga
# Processing Record 44 of Set 3 | wajid
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | lata
# Processing Record 47 of Set 3 | ballina
# Processing Record 48 of Set 3 | auki
# Processing Record 49 of Set 3 | elko
# Processing Record 50 of Set 3 | jalu
# Processing Record 1 of Set 4 | fortuna
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | sri aman
# Processing Record 4 of Set 4 | vegreville
# Processing Record 5 of Set 4 | port blair
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | salalah
# Processing Record 8 of Set 4 | ahuimanu
# Processing Record 9 of Set 4 | nuuk
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 12 of Set 4 | tuatapere
# Processing Record 13 of Set 4 | rosetown
# Processing Record 14 of Set 4 | cedar falls
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | bayamo
# Processing Record 17 of Set 4 | amasia
# Processing Record 18 of Set 4 | hammerfest
# Processing Record 19 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 4 | te kauwhata
# Processing Record 21 of Set 4 | inuvik
# Processing Record 22 of Set 4 | san quintin
# Processing Record 23 of Set 4 | jumla
# Processing Record 24 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 4 | vila franca do campo
# Processing Record 26 of Set 4 | kieta
# Processing Record 27 of Set 4 | puri
# Processing Record 28 of Set 4 | suntar
# Processing Record 29 of Set 4 | nantucket
# Processing Record 30 of Set 4 | namibe
# Processing Record 31 of Set 4 | dharchula
# Processing Record 32 of Set 4 | brookhaven
# Processing Record 33 of Set 4 | cayenne
# Processing Record 34 of Set 4 | constitucion
# Processing Record 35 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 4 | urfa
# City not found. Skipping...
# Processing Record 37 of Set 4 | labuhan
# Processing Record 38 of Set 4 | sal rei
# Processing Record 39 of Set 4 | xining
# Processing Record 40 of Set 4 | bethel
# Processing Record 41 of Set 4 | high level
# Processing Record 42 of Set 4 | sinnamary
# Processing Record 43 of Set 4 | ponedera
# Processing Record 44 of Set 4 | westport
# Processing Record 45 of Set 4 | lagoa
# Processing Record 46 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 4 | barzas
# Processing Record 48 of Set 4 | cidreira
# Processing Record 49 of Set 4 | narsaq
# Processing Record 50 of Set 4 | atar
# Processing Record 1 of Set 5 | priupskiy
# Processing Record 2 of Set 5 | izhma
# Processing Record 3 of Set 5 | los santos
# Processing Record 4 of Set 5 | lesosibirsk
# Processing Record 5 of Set 5 | northam
# Processing Record 6 of Set 5 | mao
# Processing Record 7 of Set 5 | xapuri
# Processing Record 8 of Set 5 | zafra
# Processing Record 9 of Set 5 | nalobikha
# Processing Record 10 of Set 5 | qui nhon
# Processing Record 11 of Set 5 | tautira
# Processing Record 12 of Set 5 | tupik
# Processing Record 13 of Set 5 | zugdidi
# Processing Record 14 of Set 5 | vao
# Processing Record 15 of Set 5 | waipawa
# Processing Record 16 of Set 5 | dandong
# Processing Record 17 of Set 5 | hokitika
# Processing Record 18 of Set 5 | hasaki
# Processing Record 19 of Set 5 | manaquiri
# Processing Record 20 of Set 5 | juegang
# Processing Record 21 of Set 5 | kachikau
# City not found. Skipping...
# Processing Record 22 of Set 5 | torbay
# Processing Record 23 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 5 | muroto
# Processing Record 25 of Set 5 | belozerskoye
# Processing Record 26 of Set 5 | thaba-tseka
# Processing Record 27 of Set 5 | college
# Processing Record 28 of Set 5 | belle fourche
# Processing Record 29 of Set 5 | airai
# Processing Record 30 of Set 5 | kharan
# Processing Record 31 of Set 5 | hambantota
# Processing Record 32 of Set 5 | sandy bay
# Processing Record 33 of Set 5 | hede
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | jamestown
# Processing Record 36 of Set 5 | medicine hat
# Processing Record 37 of Set 5 | san cristobal
# Processing Record 38 of Set 5 | terrace
# Processing Record 39 of Set 5 | yeppoon
# Processing Record 40 of Set 5 | hilo
# Processing Record 41 of Set 5 | pontes e lacerda
# Processing Record 42 of Set 5 | victoria
# Processing Record 43 of Set 5 | vila velha
# Processing Record 44 of Set 5 | huarmey
# Processing Record 45 of Set 5 | burgersdorp
# Processing Record 46 of Set 5 | shimoda
# Processing Record 47 of Set 5 | ponta do sol
# Processing Record 48 of Set 5 | oussouye
# Processing Record 49 of Set 5 | tigzirt
# Processing Record 50 of Set 5 | wenling
# Processing Record 1 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 6 | chara
# Processing Record 3 of Set 6 | santa isabel
# Processing Record 4 of Set 6 | datong
# Processing Record 5 of Set 6 | broken hill
# Processing Record 6 of Set 6 | kropotkin
# Processing Record 7 of Set 6 | aklavik
# Processing Record 8 of Set 6 | stromness
# Processing Record 9 of Set 6 | la rioja
# Processing Record 10 of Set 6 | saint-pierre
# Processing Record 11 of Set 6 | tiksi
# Processing Record 12 of Set 6 | truth or consequences
# Processing Record 13 of Set 6 | patrasaer
# Processing Record 14 of Set 6 | nanzhou
# Processing Record 15 of Set 6 | palmer
# Processing Record 16 of Set 6 | trairi
# Processing Record 17 of Set 6 | butaritari
# Processing Record 18 of Set 6 | dunedin
# Processing Record 19 of Set 6 | kabanjahe
# Processing Record 20 of Set 6 | lorengau
# Processing Record 21 of Set 6 | zhigansk
# Processing Record 22 of Set 6 | kununurra
# Processing Record 23 of Set 6 | itaituba
# Processing Record 24 of Set 6 | pevek
# Processing Record 25 of Set 6 | tarko-sale
# Processing Record 26 of Set 6 | mucurapo
# Processing Record 27 of Set 6 | carnarvon
# Processing Record 28 of Set 6 | sao filipe
# Processing Record 29 of Set 6 | sioux lookout
# Processing Record 30 of Set 6 | vieques
# Processing Record 31 of Set 6 | ust-kuyga
# Processing Record 32 of Set 6 | kaitangata
# Processing Record 33 of Set 6 | manzhouli
# Processing Record 34 of Set 6 | omboue
# Processing Record 35 of Set 6 | bathsheba
# Processing Record 36 of Set 6 | karratha
# Processing Record 37 of Set 6 | chokurdakh
# Processing Record 38 of Set 6 | margate
# Processing Record 39 of Set 6 | tabas
# Processing Record 40 of Set 6 | galesong
# Processing Record 41 of Set 6 | nanortalik
# Processing Record 42 of Set 6 | leeuwarden
# Processing Record 43 of Set 6 | nhulunbuy
# Processing Record 44 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 6 | sao paulo de olivenca
# Processing Record 46 of Set 6 | korla
# Processing Record 47 of Set 6 | ladispoli
# Processing Record 48 of Set 6 | haines junction
# Processing Record 49 of Set 6 | kuminskiy
# Processing Record 50 of Set 6 | matara
# Processing Record 1 of Set 7 | yandyki
# Processing Record 2 of Set 7 | fairbanks
# Processing Record 3 of Set 7 | iquitos
# Processing Record 4 of Set 7 | sesvete
# Processing Record 5 of Set 7 | bengkulu
# Processing Record 6 of Set 7 | rio gallegos
# Processing Record 7 of Set 7 | bambous virieux
# Processing Record 8 of Set 7 | shasta lake
# Processing Record 9 of Set 7 | tabora
# Processing Record 10 of Set 7 | aksu
# Processing Record 11 of Set 7 | aripuana
# Processing Record 12 of Set 7 | madras
# Processing Record 13 of Set 7 | goedereede
# Processing Record 14 of Set 7 | newton stewart
# Processing Record 15 of Set 7 | itoman
# Processing Record 16 of Set 7 | meulaboh
# Processing Record 17 of Set 7 | hoopstad
# Processing Record 18 of Set 7 | marawi
# Processing Record 19 of Set 7 | copperas cove
# Processing Record 20 of Set 7 | russell
# Processing Record 21 of Set 7 | boyolangu
# Processing Record 22 of Set 7 | pemba
# Processing Record 23 of Set 7 | clyde river
# Processing Record 24 of Set 7 | payo
# Processing Record 25 of Set 7 | anadyr
# Processing Record 26 of Set 7 | tam ky
# Processing Record 27 of Set 7 | panguna
# Processing Record 28 of Set 7 | kaeo
# Processing Record 29 of Set 7 | bandarbeyla
# Processing Record 30 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 7 | kloulklubed
# Processing Record 32 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 7 | ostersund
# Processing Record 34 of Set 7 | tecoanapa
# Processing Record 35 of Set 7 | grindavik
# Processing Record 36 of Set 7 | oster
# Processing Record 37 of Set 7 | nador
# Processing Record 38 of Set 7 | talcahuano
# Processing Record 39 of Set 7 | barcelos
# Processing Record 40 of Set 7 | bredasdorp
# Processing Record 41 of Set 7 | zalegoshch
# Processing Record 42 of Set 7 | ust-koksa
# Processing Record 43 of Set 7 | jinchang
# Processing Record 44 of Set 7 | alanya
# Processing Record 45 of Set 7 | kumluca
# Processing Record 46 of Set 7 | hirara
# Processing Record 47 of Set 7 | yantal
# Processing Record 48 of Set 7 | salamiyah
# Processing Record 49 of Set 7 | broome
# Processing Record 50 of Set 7 | padilla
# Processing Record 1 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 8 | laguna
# Processing Record 3 of Set 8 | kamenka
# Processing Record 4 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 5 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 8 | awbari
# Processing Record 7 of Set 8 | puerto suarez
# Processing Record 8 of Set 8 | katsuura
# Processing Record 9 of Set 8 | zhuanghe
# Processing Record 10 of Set 8 | yepifan
# Processing Record 11 of Set 8 | kirkwall
# Processing Record 12 of Set 8 | santa lucia
# Processing Record 13 of Set 8 | storm lake
# Processing Record 14 of Set 8 | arlit
# Processing Record 15 of Set 8 | padang
# Processing Record 16 of Set 8 | mayo
# Processing Record 17 of Set 8 | gat
# Processing Record 18 of Set 8 | anito
# Processing Record 19 of Set 8 | merauke
# Processing Record 20 of Set 8 | lincoln
# Processing Record 21 of Set 8 | bend
# Processing Record 22 of Set 8 | hounde
# Processing Record 23 of Set 8 | kurilsk
# Processing Record 24 of Set 8 | nabire
# Processing Record 25 of Set 8 | payson
# Processing Record 26 of Set 8 | atbasar
# Processing Record 27 of Set 8 | reconquista
# Processing Record 28 of Set 8 | safranbolu
# Processing Record 29 of Set 8 | terrace bay
# Processing Record 30 of Set 8 | lavrentiya
# Processing Record 31 of Set 8 | upata
# Processing Record 32 of Set 8 | kysyl-syr
# Processing Record 33 of Set 8 | erpeli
# Processing Record 34 of Set 8 | micomeseng
# Processing Record 35 of Set 8 | uralets
# Processing Record 36 of Set 8 | vung tau
# Processing Record 37 of Set 8 | kulevcha
# Processing Record 38 of Set 8 | east london
# Processing Record 39 of Set 8 | sterling
# Processing Record 40 of Set 8 | gubskaya
# Processing Record 41 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 8 | cossato
# Processing Record 43 of Set 8 | bar harbor
# Processing Record 44 of Set 8 | ushumun
# Processing Record 45 of Set 8 | yingkou
# Processing Record 46 of Set 8 | ambulu
# Processing Record 47 of Set 8 | derzhavinsk
# Processing Record 48 of Set 8 | rawson
# Processing Record 49 of Set 8 | annau
# Processing Record 50 of Set 8 | axim
# Processing Record 1 of Set 9 | namatanai
# Processing Record 2 of Set 9 | pangody
# Processing Record 3 of Set 9 | sovetskiy
# Processing Record 4 of Set 9 | qaqortoq
# Processing Record 5 of Set 9 | hualmay
# Processing Record 6 of Set 9 | puerto colombia
# Processing Record 7 of Set 9 | pimentel
# Processing Record 8 of Set 9 | mitsamiouli
# Processing Record 9 of Set 9 | port augusta
# Processing Record 10 of Set 9 | morondava
# Processing Record 11 of Set 9 | kupang
# Processing Record 12 of Set 9 | henties bay
# Processing Record 13 of Set 9 | tambacounda
# Processing Record 14 of Set 9 | severnyy
# Processing Record 15 of Set 9 | malanje
# Processing Record 16 of Set 9 | ancud
# Processing Record 17 of Set 9 | snezhnogorsk
# Processing Record 18 of Set 9 | mahebourg
# Processing Record 19 of Set 9 | honningsvag
# Processing Record 20 of Set 9 | cockburn town
# Processing Record 21 of Set 9 | mirabad
# Processing Record 22 of Set 9 | benjamin constant
# Processing Record 23 of Set 9 | disraeli
# Processing Record 24 of Set 9 | nuqui
# Processing Record 25 of Set 9 | kutum
# Processing Record 26 of Set 9 | suifenhe
# Processing Record 27 of Set 9 | oistins
# Processing Record 28 of Set 9 | medea
# Processing Record 29 of Set 9 | taoudenni
# Processing Record 30 of Set 9 | saint george
# Processing Record 31 of Set 9 | livingston
# Processing Record 32 of Set 9 | guryevsk
# Processing Record 33 of Set 9 | praia da vitoria
# Processing Record 34 of Set 9 | belmonte
# Processing Record 35 of Set 9 | manono
# Processing Record 36 of Set 9 | rockport
# Processing Record 37 of Set 9 | roald
# Processing Record 38 of Set 9 | acapulco
# Processing Record 39 of Set 9 | cumana
# Processing Record 40 of Set 9 | balkanabat
# Processing Record 41 of Set 9 | helena
# Processing Record 42 of Set 9 | slanic-moldova
# Processing Record 43 of Set 9 | harper
# Processing Record 44 of Set 9 | santa maria
# Processing Record 45 of Set 9 | nome
# Processing Record 46 of Set 9 | portland
# Processing Record 47 of Set 9 | inirida
# Processing Record 48 of Set 9 | gamboula
# Processing Record 49 of Set 9 | staryy nadym
# Processing Record 50 of Set 9 | cordele
# Processing Record 1 of Set 10 | porto torres
# Processing Record 2 of Set 10 | sola
# Processing Record 3 of Set 10 | chicama
# Processing Record 4 of Set 10 | ostrovnoy
# Processing Record 5 of Set 10 | barra
# Processing Record 6 of Set 10 | flin flon
# Processing Record 7 of Set 10 | richards bay
# Processing Record 8 of Set 10 | mulchen
# Processing Record 9 of Set 10 | voznesenye
# Processing Record 10 of Set 10 | caconda
# Processing Record 11 of Set 10 | stornoway
# Processing Record 12 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 13 of Set 10 | weinsberg
# Processing Record 14 of Set 10 | balod
# Processing Record 15 of Set 10 | hervey bay
# Processing Record 16 of Set 10 | iqaluit
# Processing Record 17 of Set 10 | ahipara
# Processing Record 18 of Set 10 | dano
# Processing Record 19 of Set 10 | carire
# Processing Record 20 of Set 10 | yaan
# Processing Record 21 of Set 10 | baykit
# Processing Record 22 of Set 10 | dannenberg
# Processing Record 23 of Set 10 | baft
# Processing Record 24 of Set 10 | nago
# Processing Record 25 of Set 10 | mwinilunga
# Processing Record 26 of Set 10 | pangnirtung
# Processing Record 27 of Set 10 | nizhniy kuranakh
# Processing Record 28 of Set 10 | kyabram
# Processing Record 29 of Set 10 | san jose
# Processing Record 30 of Set 10 | bogorodskoye
# Processing Record 31 of Set 10 | tual
# Processing Record 32 of Set 10 | oum hadjer
# Processing Record 33 of Set 10 | alberdi
# Processing Record 34 of Set 10 | novikovo
# Processing Record 35 of Set 10 | yarada
# Processing Record 36 of Set 10 | komsomolskiy
# Processing Record 37 of Set 10 | oskarshamn
# Processing Record 38 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 10 | metro
# Processing Record 40 of Set 10 | matagami
# Processing Record 41 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 42 of Set 10 | urumqi
# Processing Record 43 of Set 10 | murdochville
# Processing Record 44 of Set 10 | diffa
# Processing Record 45 of Set 10 | leshukonskoye
# Processing Record 46 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 10 | zaykovo
# Processing Record 48 of Set 10 | rio grande
# Processing Record 49 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 10 | yinchuan
# Processing Record 1 of Set 11 | adamas
# Processing Record 2 of Set 11 | ukiah
# Processing Record 3 of Set 11 | mount isa
# Processing Record 4 of Set 11 | poya
# Processing Record 5 of Set 11 | leningradskiy
# Processing Record 6 of Set 11 | visby
# Processing Record 7 of Set 11 | reshetylivka
# Processing Record 8 of Set 11 | eyl
# Processing Record 9 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 10 of Set 11 | othonoi
# City not found. Skipping...
# Processing Record 11 of Set 11 | hakvik
# City not found. Skipping...
# Processing Record 12 of Set 11 | parana
# Processing Record 13 of Set 11 | boguchany
# Processing Record 14 of Set 11 | vanimo
# Processing Record 15 of Set 11 | cove
# Processing Record 16 of Set 11 | san patricio
# Processing Record 17 of Set 11 | buckingham
# Processing Record 18 of Set 11 | kirakira
# Processing Record 19 of Set 11 | starogard gdanski
# Processing Record 20 of Set 11 | el alto
# Processing Record 21 of Set 11 | andros town
# Processing Record 22 of Set 11 | vardo
# Processing Record 23 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 11 | coronado
# Processing Record 25 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 26 of Set 11 | srandakan
# Processing Record 27 of Set 11 | mangochi
# Processing Record 28 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 11 | shu
# Processing Record 31 of Set 11 | nishihara
# Processing Record 32 of Set 11 | winnemucca
# Processing Record 33 of Set 11 | tanjong karang
# City not found. Skipping...
# Processing Record 34 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 11 | bonavista
# Processing Record 36 of Set 11 | ust-tarka
# Processing Record 37 of Set 11 | lannion
# Processing Record 38 of Set 11 | coihaique
# Processing Record 39 of Set 11 | tselinnoye
# Processing Record 40 of Set 11 | chapais
# Processing Record 41 of Set 11 | aswan
# Processing Record 42 of Set 11 | faya
# Processing Record 43 of Set 11 | wagga wagga
# Processing Record 44 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 11 | beihai
# Processing Record 46 of Set 11 | tripoli
# Processing Record 47 of Set 11 | guebwiller
# Processing Record 48 of Set 11 | sangmelima
# Processing Record 49 of Set 11 | saurimo
# Processing Record 50 of Set 11 | huanren
# Processing Record 1 of Set 12 | khandyga
# Processing Record 2 of Set 12 | polyarnyy
# Processing Record 3 of Set 12 | kikwit
# Processing Record 4 of Set 12 | den helder
# Processing Record 5 of Set 12 | gormi
# City not found. Skipping...
# Processing Record 6 of Set 12 | zitiste
# Processing Record 7 of Set 12 | madison
# Processing Record 8 of Set 12 | zaysan
# Processing Record 9 of Set 12 | pareora
# Processing Record 10 of Set 12 | mogadishu
# Processing Record 11 of Set 12 | evensk
# Processing Record 12 of Set 12 | senneterre
# Processing Record 13 of Set 12 | bocas del toro
# Processing Record 14 of Set 12 | sakaiminato
# Processing Record 15 of Set 12 | phulabani
# Processing Record 16 of Set 12 | quatre cocos
# Processing Record 17 of Set 12 | zehdenick
# Processing Record 18 of Set 12 | narkanda
# Processing Record 19 of Set 12 | bose
# Processing Record 20 of Set 12 | nara
# Processing Record 21 of Set 12 | labuan
# Processing Record 22 of Set 12 | semirom
# Processing Record 23 of Set 12 | alofi
# Processing Record 24 of Set 12 | loei
# Processing Record 25 of Set 12 | omsukchan
# Processing Record 26 of Set 12 | kangundo
# Processing Record 27 of Set 12 | manitouwadge
# Processing Record 28 of Set 12 | launceston
# Processing Record 29 of Set 12 | vancouver
# Processing Record 30 of Set 12 | lundazi
# Processing Record 31 of Set 12 | ibb
# Processing Record 32 of Set 12 | hovd
# Processing Record 33 of Set 12 | yulara
# Processing Record 34 of Set 12 | tukums
# Processing Record 35 of Set 12 | los lunas
# Processing Record 36 of Set 12 | almeria
# Processing Record 37 of Set 12 | adrar
# Processing Record 38 of Set 12 | tra vinh
# Processing Record 39 of Set 12 | comodoro rivadavia
# Processing Record 40 of Set 12 | pueblo nuevo
# Processing Record 41 of Set 12 | ipixuna
# Processing Record 42 of Set 12 | sungai besar
# Processing Record 43 of Set 12 | atikokan
# Processing Record 44 of Set 12 | skierniewice
# Processing Record 45 of Set 12 | barsovo
# Processing Record 46 of Set 12 | beringovskiy
# Processing Record 47 of Set 12 | plettenberg bay
# Processing Record 48 of Set 12 | berlin
# Processing Record 49 of Set 12 | moree
# Processing Record 50 of Set 12 | las tunas
# Processing Record 1 of Set 13 | puerto leguizamo
# Processing Record 2 of Set 13 | calama
# Processing Record 3 of Set 13 | manjeshwar
# Processing Record 4 of Set 13 | lashio
# Processing Record 5 of Set 13 | yate
# Processing Record 6 of Set 13 | conde
# Processing Record 7 of Set 13 | dubno
# Processing Record 8 of Set 13 | lazaro cardenas
# Processing Record 9 of Set 13 | brookings
# Processing Record 10 of Set 13 | bilibino
# Processing Record 11 of Set 13 | wageningen
# Processing Record 12 of Set 13 | abu samrah
# Processing Record 13 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 15 of Set 13 | sandnessjoen
# Processing Record 16 of Set 13 | oshkosh
# Processing Record 17 of Set 13 | dali
# Processing Record 18 of Set 13 | farkhor
# Processing Record 19 of Set 13 | bangolo
# Processing Record 20 of Set 13 | cairns
# Processing Record 21 of Set 13 | mutuipe
# Processing Record 22 of Set 13 | vikhorevka
# Processing Record 23 of Set 13 | severnyy-kospashskiy
# Processing Record 24 of Set 13 | matanzas
# Processing Record 25 of Set 13 | mingaora
# Processing Record 26 of Set 13 | talnakh
# Processing Record 27 of Set 13 | kuva
# City not found. Skipping...
# Processing Record 28 of Set 13 | warrnambool
# Processing Record 29 of Set 13 | norrtalje
# Processing Record 30 of Set 13 | ellsworth
# Processing Record 31 of Set 13 | constantine
# Processing Record 32 of Set 13 | gimli
# Processing Record 33 of Set 13 | tres palos
# Processing Record 34 of Set 13 | toyooka
# Processing Record 35 of Set 13 | warmbad
# Processing Record 36 of Set 13 | narkevychi
# Processing Record 37 of Set 13 | byron bay
# Processing Record 38 of Set 13 | falevao
# City not found. Skipping...
# Processing Record 39 of Set 13 | sulangan
# Processing Record 40 of Set 13 | aykhal
# Processing Record 41 of Set 13 | garissa
# Processing Record 42 of Set 13 | floro
# Processing Record 43 of Set 13 | sabang
# Processing Record 44 of Set 13 | sao gabriel da cachoeira
# Processing Record 45 of Set 13 | posadas
# Processing Record 46 of Set 13 | ambon
# Processing Record 47 of Set 13 | key largo
# Processing Record 48 of Set 13 | kampong chhnang
# Processing Record 49 of Set 13 | daru
# Processing Record 50 of Set 13 | riviere-au-renard
# Processing Record 1 of Set 14 | lucea
# Processing Record 2 of Set 14 | athabasca
# Processing Record 3 of Set 14 | akdepe
# Processing Record 4 of Set 14 | mirnyy
# Processing Record 5 of Set 14 | kalmunai
# Processing Record 6 of Set 14 | tungor
# Processing Record 7 of Set 14 | mombetsu
# Processing Record 8 of Set 14 | beloha
# Processing Record 9 of Set 14 | roebourne
# Processing Record 10 of Set 14 | mandalgovi
# Processing Record 11 of Set 14 | tazovskiy
# Processing Record 12 of Set 14 | antofagasta
# Processing Record 13 of Set 14 | pires do rio
# Processing Record 14 of Set 14 | mizdah
# Processing Record 15 of Set 14 | corum
# Processing Record 16 of Set 14 | buala
# Processing Record 17 of Set 14 | manggar
# Processing Record 18 of Set 14 | muzhi
# Processing Record 19 of Set 14 | cam ranh
# Processing Record 20 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 21 of Set 14 | bellview
# Processing Record 22 of Set 14 | goderich
# Processing Record 23 of Set 14 | koslan
# Processing Record 24 of Set 14 | batie
# Processing Record 25 of Set 14 | keti bandar
# Processing Record 26 of Set 14 | tornio
# Processing Record 27 of Set 14 | ramshir
# Processing Record 28 of Set 14 | erbaa
# Processing Record 29 of Set 14 | buenos aires
# Processing Record 30 of Set 14 | navahrudak
# Processing Record 31 of Set 14 | lewisporte
# Processing Record 32 of Set 14 | tari
# Processing Record 33 of Set 14 | cape canaveral
# Processing Record 34 of Set 14 | pervoye maya
# Processing Record 35 of Set 14 | spornoye
# Processing Record 36 of Set 14 | saint-denis
# Processing Record 37 of Set 14 | sarangarh
# Processing Record 38 of Set 14 | scottsbluff
# Processing Record 39 of Set 14 | pangkalanbuun
# Processing Record 40 of Set 14 | khangah dogran
# Processing Record 41 of Set 14 | araouane
# Processing Record 42 of Set 14 | los llanos de aridane
# Processing Record 43 of Set 14 | antalaha
# Processing Record 44 of Set 14 | muros
# Processing Record 45 of Set 14 | sirkali
# City not found. Skipping...
# Processing Record 46 of Set 14 | asyut
# Processing Record 47 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 14 | praya
# Processing Record 50 of Set 14 | skegness
# Processing Record 1 of Set 15 | iskateley
# Processing Record 2 of Set 15 | sabha
# Processing Record 3 of Set 15 | ewa beach
# Processing Record 4 of Set 15 | esso
# Processing Record 5 of Set 15 | alekseyevskoye
# Processing Record 6 of Set 15 | half moon bay
# Processing Record 7 of Set 15 | yar-sale
# Processing Record 8 of Set 15 | bilma
# Processing Record 9 of Set 15 | marovoay
# Processing Record 10 of Set 15 | sosnovo-ozerskoye
# Processing Record 11 of Set 15 | along
# Processing Record 12 of Set 15 | souris
# Processing Record 13 of Set 15 | tabuk
# Processing Record 14 of Set 15 | viedma
# Processing Record 15 of Set 15 | warwick
# Processing Record 16 of Set 15 | changji
# Processing Record 17 of Set 15 | fortuna foothills
# Processing Record 18 of Set 15 | akcakoca
# Processing Record 19 of Set 15 | camacha
# Processing Record 20 of Set 15 | gorontalo
# Processing Record 21 of Set 15 | banda aceh
# Processing Record 22 of Set 15 | guymon
# Processing Record 23 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 24 of Set 15 | krasnoselkup
# Processing Record 25 of Set 15 | kipini
# Processing Record 26 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 27 of Set 15 | easton
# Processing Record 28 of Set 15 | rumuruti
# Processing Record 29 of Set 15 | dhidhdhoo
# Processing Record 30 of Set 15 | el cocuy
# Processing Record 31 of Set 15 | kingaroy
# Processing Record 32 of Set 15 | greymouth
# Processing Record 33 of Set 15 | podosinovets
# Processing Record 34 of Set 15 | tessalit
# Processing Record 35 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 15 | rettikhovka
# Processing Record 37 of Set 15 | virginia beach
# Processing Record 38 of Set 15 | kaputa
# Processing Record 39 of Set 15 | sungaipenuh
# Processing Record 40 of Set 15 | shahrud
# Processing Record 41 of Set 15 | zhanakorgan
# Processing Record 42 of Set 15 | abu dhabi
# Processing Record 43 of Set 15 | izumo
# Processing Record 44 of Set 15 | emba
# Processing Record 45 of Set 15 | natal
# Processing Record 46 of Set 15 | pravda
# Processing Record 47 of Set 15 | karasjok
# Processing Record 48 of Set 15 | necochea
# Processing Record 49 of Set 15 | kosh-agach
# Processing Record 50 of Set 15 | okha
# Processing Record 1 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 16 | raudeberg
# Processing Record 3 of Set 16 | acarau
# Processing Record 4 of Set 16 | sorland
# Processing Record 5 of Set 16 | moussoro
# Processing Record 6 of Set 16 | newark
# Processing Record 7 of Set 16 | hadejia
# Processing Record 8 of Set 16 | kholodnyy
# Processing Record 9 of Set 16 | kavaratti
# Processing Record 10 of Set 16 | deputatskiy
# Processing Record 11 of Set 16 | gizo
# Processing Record 12 of Set 16 | ishigaki
# Processing Record 13 of Set 16 | bulawayo
# Processing Record 14 of Set 16 | mbandaka
# Processing Record 15 of Set 16 | imbituba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severo-Kurilsk      RU  50.6789  156.1250     27.50        94         100
# 1       Busselton      AU -33.6500  115.3333     63.09        65          88
# 2        Thompson      CA  55.7435  -97.8558      6.96        72          20
# 3           Lagos      NG   6.5833    3.7500     82.72        63          39
# 4          Palana      RU  59.1167  159.9667     26.69        72         100
# 5          Kodiak      US  57.7900 -152.4072     26.11        68          75
# 6          Azuaga      ES  38.2667   -5.6833     52.97        40          49
# 7        Coquimbo      CL -29.9533  -71.3436     69.53        68           0
# 8          Atuona      PF  -9.8000 -139.0333     77.85        76          18
# 9        Hermanus      ZA -34.4187   19.2345     70.81        82         100
#
#    Wind Speed Current Description
# 0       13.67                snow
# 1       18.79     overcast clouds
# 2        2.30          few clouds
# 3        3.06    scattered clouds
# 4       26.62     overcast clouds
# 5       12.66       broken clouds
# 6        0.38    scattered clouds
# 7       11.50           clear sky
# 8       14.23          few clouds
# 9       14.25     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
export_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(export_file, index_label="City_ID")
