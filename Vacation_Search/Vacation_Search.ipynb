# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
import sys
# !{sys.executable} -m pip install gmaps
# Out:
# Requirement already satisfied: gmaps in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (0.9.0)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (5.1.0)
# Requirement already satisfied: geojson>=2.0.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: six in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (7.29.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: appnope in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: pickleshare in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: decorator in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.18.0)
# Requirement already satisfied: backcall in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: pygments in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (2.10.0)
# Requirement already satisfied: pexpect>4.3 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (6.4.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.2.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.5)
# Requirement already satisfied: terminado>=0.8.3 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.4)
# Requirement already satisfied: prometheus-client in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.11.0)
# Requirement already satisfied: jinja2 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: nbconvert in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: argon2-cffi in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.6)
# Requirement already satisfied: pycparser in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: defusedxml in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: testpath in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.3)
# Requirement already satisfied: bleach in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: async-generator in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: packaging in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.0)
# Requirement already satisfied: webencodings in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/katmarcin/opt/anaconda3/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Severo-Kurilsk      RU  50.6789  156.1250     27.50        94
# 1        1       Busselton      AU -33.6500  115.3333     63.09        65
# 2        2        Thompson      CA  55.7435  -97.8558      6.96        72
# 3        3           Lagos      NG   6.5833    3.7500     82.72        63
# 4        4          Palana      RU  59.1167  159.9667     26.69        72
#
#    Cloudiness  Wind Speed Current Description
# 0         100       13.67                snow
# 1          88       18.79     overcast clouds
# 2          20        2.30          few clouds
# 3          39        3.06    scattered clouds
# 4         100       26.62     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 

min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.

preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 3         3            Lagos      NG   6.5833    3.7500     82.72        63
# 8         8           Atuona      PF  -9.8000 -139.0333     77.85        76
# 9         9         Hermanus      ZA -34.4187   19.2345     70.81        82
# 11       11   Port Elizabeth      ZA -33.9180   25.5701     74.10        88
# 15       15  Arraial Do Cabo      BR -22.9661  -42.0278     82.36        74
# 16       16           Avarua      CK -21.2078 -159.7750     73.45        94
# 19       19           Touros      BR  -5.1989  -35.4608     85.10        71
# 22       22           Tumaco      CO   1.7986  -78.8156     78.57        80
# 24       24              Gao      ML  16.6362    1.6370     72.16        13
# 29       29      Mancio Lima      BR  -7.6142  -72.8958     80.67        83
#
#     Cloudiness  Wind Speed Current Description
# 3           39        3.06    scattered clouds
# 8           18       14.23          few clouds
# 9          100       14.25     overcast clouds
# 11          20       14.97          few clouds
# 15          40        4.61    scattered clouds
# 16          75        3.44          light rain
# 19          96       13.09     overcast clouds
# 22         100        6.15     overcast clouds
# 24           1       12.15           clear sky
# 29          75        6.91       broken clouds

# %%
# 4a. Determine if there are any empty rows.

preferred_cities_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                1
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.

clean_df = preferred_cities_df.dropna()
clean_df
# Out:
#      City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 3          3            Lagos      NG   6.5833    3.7500     82.72        63
# 8          8           Atuona      PF  -9.8000 -139.0333     77.85        76
# 9          9         Hermanus      ZA -34.4187   19.2345     70.81        82
# 11        11   Port Elizabeth      ZA -33.9180   25.5701     74.10        88
# 15        15  Arraial Do Cabo      BR -22.9661  -42.0278     82.36        74
# ..       ...              ...     ...      ...       ...       ...       ...
# 696      696           Acarau      BR  -2.8856  -40.1200     77.31        84
# 702      702        Kavaratti      IN  10.5669   72.6420     81.28        73
# 704      704             Gizo      SB  -8.1030  156.8419     82.96        76
# 707      707         Mbandaka      CD   0.0487   18.2603     77.90        37
# 708      708         Imbituba      BR -28.2400  -48.6703     75.09        63
#
#      Cloudiness  Wind Speed Current Description
# 3            39        3.06    scattered clouds
# 8            18       14.23          few clouds
# 9           100       14.25     overcast clouds
# 11           20       14.97          few clouds
# 15           40        4.61    scattered clouds
# ..          ...         ...                 ...
# 696         100        9.31     overcast clouds
# 702          15        8.79          few clouds
# 704         100        8.66          light rain
# 707         100        3.56     overcast clouds
# 708          50        5.79    scattered clouds
#
# [238 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 3             Lagos      NG     82.72    scattered clouds   6.5833    3.7500
# 8            Atuona      PF     77.85          few clouds  -9.8000 -139.0333
# 9          Hermanus      ZA     70.81     overcast clouds -34.4187   19.2345
# 11   Port Elizabeth      ZA     74.10          few clouds -33.9180   25.5701
# 15  Arraial Do Cabo      BR     82.36    scattered clouds -22.9661  -42.0278
# 16           Avarua      CK     73.45          light rain -21.2078 -159.7750
# 19           Touros      BR     85.10     overcast clouds  -5.1989  -35.4608
# 22           Tumaco      CO     78.57     overcast clouds   1.7986  -78.8156
# 24              Gao      ML     72.16           clear sky  16.6362    1.6370
# 29      Mancio Lima      BR     80.67       broken clouds  -7.6142  -72.8958
#
#    Hotel Name
# 3
# 8
# 9
# 11
# 15
# 16
# 19
# 22
# 24
# 29

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.

for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame

    lat = row["Lat"]
    lng = row["Lng"]    

    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
   
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
      print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
import numpy as np

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()
clean_hotel_df.head(20)
# Out:
#                          City Country  Max Temp Current Description      Lat  \
# 8                      Atuona      PF     77.85          few clouds  -9.8000
# 9                    Hermanus      ZA     70.81     overcast clouds -34.4187
# 11             Port Elizabeth      ZA     74.10          few clouds -33.9180
# 15            Arraial Do Cabo      BR     82.36    scattered clouds -22.9661
# 16                     Avarua      CK     73.45          light rain -21.2078
# 19                     Touros      BR     85.10     overcast clouds  -5.1989
# 22                     Tumaco      CO     78.57     overcast clouds   1.7986
# 29                Mancio Lima      BR     80.67       broken clouds  -7.6142
# 30               Puerto Ayora      EC     82.36     overcast clouds  -0.7393
# 31                     Faanui      PF     80.28    scattered clouds -16.4833
# 38                     Manaus      BR     82.90       broken clouds  -3.1019
# 40                    Kahului      US     78.84           clear sky  20.8947
# 41                       Chuy      UY     79.07    scattered clouds -33.6971
# 43                    Rikitea      PF     76.33     overcast clouds -23.1203
# 44                      Kapaa      US     77.32          few clouds  22.0752
# 45                   Ambilobe      MG     75.43     overcast clouds -13.2000
# 47                      Vaini      TO     80.06          light rain -21.2000
# 48  San Pedro De Los Naranjos      MX     76.39           clear sky  20.2500
# 51                 Luganville      VU     76.73     overcast clouds -15.5333
# 54             Cabo San Lucas      MX     79.90          few clouds  22.8909
#
#          Lng                           Hotel Name
# 8  -139.0333                          Villa Enata
# 9    19.2345           Misty Waves Boutique Hotel
# 11   25.5701               39 On Nile Guest House
# 15  -42.0278                  Pousada Porto Praia
# 16 -159.7750                         Paradise Inn
# 19  -35.4608                      INN NEW HORIZON
# 22  -78.8156                           Dafneruben
# 29  -72.8958                 Motel Asas Do Desejo
# 30  -90.3518            Finch Bay Galapagos Hotel
# 31 -151.7500   Bora-Bora Pearl Beach Resort & Spa
# 38  -60.0250             Manaus Hotéis Millennium
# 40 -156.4700                   Maui Seaside Hotel
# 41  -53.4616                    Nuevo Hotel Plaza
# 43 -134.9692                      People ThankYou
# 44 -159.3190  Sheraton Kauai Coconut Beach Resort
# 45   49.0500    Hôtel & Restaurant DIANA Ambilobe
# 47 -175.2000                  Keleti Beach Resort
# 48 -100.9833                       Antiguo Molino
# 51  167.1667                   The Espiritu Hotel
# 54 -109.9124               Hotel Tesoro Los Cabos

# %%
clean_hotel_df.isnull().sum()
# Out:
# City                   0
# Country                0
# Max Temp               0
# Current Description    0
# Lat                    0
# Lng                    0
# Hotel Name             0
# dtype: int64

# %%
# 8a. Create the output File (CSV)

output_vacation_search= "WeatherPy_Vacation.csv"


# 8b. Export the City_Data into a csv

hotel_df.to_csv(output_vacation_search, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description, and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""
# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

# 11b. Display the figure

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.75)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
